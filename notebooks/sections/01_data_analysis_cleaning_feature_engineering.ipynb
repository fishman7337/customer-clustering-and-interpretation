# %% [markdown]
# <hr/>
# <h1>2. Data Analysis</h1>

# %% [markdown]
# <p>In this section, I will be conducting simple Data Analysis to understand the dataset provided at a deeper level. By conducting Data Analysis, I will be able to evaluate what I need to do and subsequently, path the way for other operations that need to be conducted. This section is extremely important as without doing a proper Data Analysis, I will not be able to train the Unsupervised Model effectively and may even encounter errors within the datasets due to poor planning that occured due to a poor Data Analysis conducted by me.</p>

# %% [markdown]
# <hr/>
# <h2>2.1 Importing of CSV File</h2>

# %% [markdown]
# <p>Before performing Data Analysis, I will need to import the CSV file that has been provided to me. By performing the operation as shown in the cell below, I have also directly placed the CSV File into a dataframe which allows me to perform various operation on it afterwards.</p>

# %%
# ----------- Importing of CSV File ---------- #
df = pd.read_csv("../data/raw/CA2-Customer-Data.csv", sep = ",")

# ----------- Execution Confirmation ----------- #
print("CSV File Successfully Imported")
# Out:
# CSV File Successfully Imported

# %% [markdown]
# <p>As shown in the cell above, the text 'CSV File Successfully Imported' shows that the previous line of code which is meant to import the CSV File has been successfully executed and that 'df' now holds the dataframe that is related to the CSV File.</p>

# %% [markdown]
# <hr/>
# <h2>2.2 Reading of CSV File</h2>

# %% [markdown]
# <p>After successfully importing the CSV File as 'df', I will be taking a look at the first 10 data rows of the dataframe. I will then evaluate what needs to be done regarding the dataset that has been provided.</p>

# %%
# ------------- Displaying DataFrame ----------- #
df.head(10).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_460a7_row0_col0, #T_460a7_row0_col2, #T_460a7_row0_col3, #T_460a7_row1_col3, #T_460a7_row8_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_460a7_row0_col4 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_460a7_row1_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_460a7_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_460a7_row1_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_460a7_row2_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_460a7_row2_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_460a7_row2_col3, #T_460a7_row3_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_460a7_row2_col4, #T_460a7_row6_col4 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_460a7_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_460a7_row3_col2, #T_460a7_row7_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_460a7_row3_col4 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_460a7_row4_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_460a7_row4_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_460a7_row4_col3, #T_460a7_row5_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_460a7_row4_col4 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_460a7_row5_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_460a7_row5_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_460a7_row5_col4 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_460a7_row6_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_460a7_row6_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_460a7_row6_col3, #T_460a7_row7_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_460a7_row7_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_460a7_row7_col4, #T_460a7_row8_col2, #T_460a7_row8_col3, #T_460a7_row9_col0, #T_460a7_row9_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_460a7_row8_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_460a7_row9_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_460a7_row9_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_460a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_460a7_level0_col0" class="col_heading level0 col0" >CustomerID</th>
#       <th id="T_460a7_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_460a7_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_460a7_level0_col3" class="col_heading level0 col3" >Income (k$)</th>
#       <th id="T_460a7_level0_col4" class="col_heading level0 col4" >How Much They Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_460a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_460a7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_460a7_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_460a7_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_460a7_row0_col3" class="data row0 col3" >15</td>
#       <td id="T_460a7_row0_col4" class="data row0 col4" >39</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_460a7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_460a7_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_460a7_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_460a7_row1_col3" class="data row1 col3" >15</td>
#       <td id="T_460a7_row1_col4" class="data row1 col4" >81</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_460a7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_460a7_row2_col1" class="data row2 col1" >Female</td>
#       <td id="T_460a7_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_460a7_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_460a7_row2_col4" class="data row2 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_460a7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_460a7_row3_col1" class="data row3 col1" >Female</td>
#       <td id="T_460a7_row3_col2" class="data row3 col2" >23</td>
#       <td id="T_460a7_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_460a7_row3_col4" class="data row3 col4" >77</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_460a7_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_460a7_row4_col1" class="data row4 col1" >Female</td>
#       <td id="T_460a7_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_460a7_row4_col3" class="data row4 col3" >17</td>
#       <td id="T_460a7_row4_col4" class="data row4 col4" >40</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_460a7_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_460a7_row5_col1" class="data row5 col1" >Female</td>
#       <td id="T_460a7_row5_col2" class="data row5 col2" >22</td>
#       <td id="T_460a7_row5_col3" class="data row5 col3" >17</td>
#       <td id="T_460a7_row5_col4" class="data row5 col4" >76</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_460a7_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_460a7_row6_col1" class="data row6 col1" >Female</td>
#       <td id="T_460a7_row6_col2" class="data row6 col2" >35</td>
#       <td id="T_460a7_row6_col3" class="data row6 col3" >18</td>
#       <td id="T_460a7_row6_col4" class="data row6 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_460a7_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_460a7_row7_col1" class="data row7 col1" >Female</td>
#       <td id="T_460a7_row7_col2" class="data row7 col2" >23</td>
#       <td id="T_460a7_row7_col3" class="data row7 col3" >18</td>
#       <td id="T_460a7_row7_col4" class="data row7 col4" >94</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_460a7_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_460a7_row8_col1" class="data row8 col1" >Male</td>
#       <td id="T_460a7_row8_col2" class="data row8 col2" >64</td>
#       <td id="T_460a7_row8_col3" class="data row8 col3" >19</td>
#       <td id="T_460a7_row8_col4" class="data row8 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_460a7_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_460a7_row9_col1" class="data row9 col1" >Female</td>
#       <td id="T_460a7_row9_col2" class="data row9 col2" >30</td>
#       <td id="T_460a7_row9_col3" class="data row9 col3" >19</td>
#       <td id="T_460a7_row9_col4" class="data row9 col4" >72</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to see that there is a total of 5 Data Column, 4 of which are Numerical Data and 1 of which is a Categorical Data. The Categorical Data needs to be converted into dummy variable but the standard method of One-Hot Encoding may not be suitable due to the requirement of Numerical Data needing to be Scaled so as to not be deemed redundant by the Clustering Model. The initial 10 rows also shows no missing data. However, this has to be fact checked later on.</p>

# %% [markdown]
# <hr/>
# <h3>2.2.1 Interpretation of CSV File's Data Column</h3>

# %% [markdown]
# <p><strong><u>CustomerID</u></strong></p>
# <ul>
#     <li>Unique to each Customer.</li>
#     <li>Does not assist in clustering. Instead, it might reduce the accuracy of the Clustering.</li>
#     <li>Does not help in improving Customer Service of Businesses.</li>
#     <li>Will not be used as a Feature due to lack of use.</li>
# </ul>
#
# <p><strong><u>Gender</u></strong></p>
# <ul>
#     <li>Gender of each Customer.</li>
#     <li>Needs to be converted to dummy variable due to Clustering Models only accepting Numerical Data.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Research shows Males to be more Functional and Outcome-oriented whereas Females focus more on Actual Service and Emotional Outcomes.</li>
#     <li>Businesses should train staff based on how to treat customers of different gender and ensuring it alligns with their satisfaction.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>
#
# <p><strong><u>Age</u></strong></p>
# <ul>
#     <li>Age of each Customer.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Research shows Customers of Older Demographics prefers Quality Face-to-Face Customer Service whereas Customers of Younger Demographics has higher expectations such as a Website, Social Media and Loyality Program.</li>
#     <li>Businesses should ensure that their Target Age Group's satisfaction is placed as the highest priority. For example, if the Target Age Group is Teenagers, Websites and Social Medias should be maintained frequently whereas if the Target Age Group is Adults, more staff should be on-site to assist them.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>
#
# <p><strong><u>Income (k$)</u></strong></p>
# <ul>
#     <li>Annual Income of each Customer.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Customers who have Higher Income may be More Demanding and Less Sensitive to Prices whereas the opposite is true for Customers with Lower Income.</li>
#     <li>Businesses should train their staff on the available inventory items' prices so as to cater to the budget of different Customers, thus creating Higher Overall Customer Satisfaction.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>
#
# <p><strong><u>How Much They Spend</u></strong></p>
# <ul>
#     <li>The Amount of Money each Customer spend.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Customers who haveHigher Spendingse may be More Demanding and Less Sensitive to Prices whereas the opposite is true for Customers with LowerSpending..</li>
#     <li>Businesses should train their staff to treat all Customers with Professionalism and without Discrimination so as to Increase Overall Customer Satisfactionn.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>

# %% [markdown]
# <hr/>
# <h2>2.3 Dropping Exclusive Data</h2>

# %% [markdown]
# <p>As observed previously, there are exclusive data that are present within the dataset. These data columns that contain the exclusive data will be dropped as they contribute nothing towards the Clustering and only serves as an Unique Identifier for all the Customers. Thus, I have come to the conclusion that dropping these exclusive data columns is neccessary.</p>

# %%
# ------------ Selecting Non-Exclusive Data Columns ---------- #
df = df.iloc[:, 1:9]

# ---------- Displaying DataFrame ------------ #
df.head(10).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_6dbed_row0_col1, #T_6dbed_row0_col2, #T_6dbed_row1_col2, #T_6dbed_row8_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6dbed_row0_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_6dbed_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6dbed_row1_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_6dbed_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_6dbed_row2_col2, #T_6dbed_row3_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_6dbed_row2_col3, #T_6dbed_row6_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6dbed_row3_col1, #T_6dbed_row7_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_6dbed_row3_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_6dbed_row4_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_6dbed_row4_col2, #T_6dbed_row5_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_6dbed_row4_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_6dbed_row5_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_6dbed_row5_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_6dbed_row6_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_6dbed_row6_col2, #T_6dbed_row7_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_6dbed_row7_col3, #T_6dbed_row8_col1, #T_6dbed_row8_col2, #T_6dbed_row9_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6dbed_row9_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_6dbed_row9_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6dbed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dbed_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_6dbed_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_6dbed_level0_col2" class="col_heading level0 col2" >Income (k$)</th>
#       <th id="T_6dbed_level0_col3" class="col_heading level0 col3" >How Much They Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dbed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dbed_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_6dbed_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_6dbed_row0_col2" class="data row0 col2" >15</td>
#       <td id="T_6dbed_row0_col3" class="data row0 col3" >39</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6dbed_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_6dbed_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_6dbed_row1_col2" class="data row1 col2" >15</td>
#       <td id="T_6dbed_row1_col3" class="data row1 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6dbed_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_6dbed_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_6dbed_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_6dbed_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6dbed_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_6dbed_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_6dbed_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_6dbed_row3_col3" class="data row3 col3" >77</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6dbed_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_6dbed_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_6dbed_row4_col2" class="data row4 col2" >17</td>
#       <td id="T_6dbed_row4_col3" class="data row4 col3" >40</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6dbed_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_6dbed_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_6dbed_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_6dbed_row5_col3" class="data row5 col3" >76</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6dbed_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_6dbed_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_6dbed_row6_col2" class="data row6 col2" >18</td>
#       <td id="T_6dbed_row6_col3" class="data row6 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6dbed_row7_col0" class="data row7 col0" >Female</td>
#       <td id="T_6dbed_row7_col1" class="data row7 col1" >23</td>
#       <td id="T_6dbed_row7_col2" class="data row7 col2" >18</td>
#       <td id="T_6dbed_row7_col3" class="data row7 col3" >94</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6dbed_row8_col0" class="data row8 col0" >Male</td>
#       <td id="T_6dbed_row8_col1" class="data row8 col1" >64</td>
#       <td id="T_6dbed_row8_col2" class="data row8 col2" >19</td>
#       <td id="T_6dbed_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6dbed_row9_col0" class="data row9 col0" >Female</td>
#       <td id="T_6dbed_row9_col1" class="data row9 col1" >30</td>
#       <td id="T_6dbed_row9_col2" class="data row9 col2" >19</td>
#       <td id="T_6dbed_row9_col3" class="data row9 col3" >72</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the cell above, I can verify that the exclusvive data columns which are 'CustomerID' have been removed as that Data Column is no longer there, leaving the rest of the Data Columns which will be used as Features.</p>

# %% [markdown]
# <hr/>
# <h2>2.4 Characteristics of Data</h2>

# %% [markdown]
# <p>In this sub-section, I will view the characteristics of my data such as the Numerical Characteristic for Numerical Data. I will also verify how large my dataset is and to verify the scale of the data that I am working with for Clustering.</p>

# %% [markdown]
# <hr/>
# <h3>2.4.1 Information of Data</h3>

# %% [markdown]
# <p>In the cell below, I will view the informaton of the dataset. The information will include the amount of data that is not missing and also the datatype for each of the Data Column. The operation will also display the total Data Rows for the dataframe.</p>

# %%
# ----------- Display Information Of DataFrame ----------- #
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               200 non-null    object
#  1   Age                  200 non-null    int64
#  2   Income (k$)          200 non-null    int64
#  3   How Much They Spend  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %% [markdown]
# <p>With reference to the output of the cell above, I am able to verify that there are no Missing Data as the RangeIndex has a total of 200 entries which matches up to the Non-Null Count which also has 200. However, this will need to be confirmed through a more conventional method later on. Through the output, I am also able to see that Gender is the only Categorical Data within the entire dataset which is supported by the previous observations in the previous subsections. Therefore, the Categorical Data need to be converted to a Numerical Data but with Scaling taken into account so as to not make Gender redundant during Clustering.</p>

# %% [markdown]
# <hr/>
# <h3>2.4.2 Shape of Data</h3>

# %% [markdown]
# <p>From the cell below, I will execute an operation which will display the amount of Data Rows and Data Columns that my dataset contains.</p>

# %%
# ----------- df's Shape ----------- #
shape_data = {'Attribute': ['Rows', 'Columns'], 'Count': list(df.shape)}

# ----------- Putting Shape Into DataFrame ----------- #
df_shape = pd.DataFrame(shape_data)

# ----------- Displaying DataFrame ----------- #
df_shape.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_fc470_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fc470_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fc470">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc470_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_fc470_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc470_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc470_row0_col0" class="data row0 col0" >Rows</td>
#       <td id="T_fc470_row0_col1" class="data row0 col1" >200</td>
#     </tr>
#     <tr>
#       <th id="T_fc470_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc470_row1_col0" class="data row1 col0" >Columns</td>
#       <td id="T_fc470_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the cell above, I am able to verify that the operation has been successfully executed. The data is represented in the format shown below. Thus, I can verify that there is a total of 200 Data Rows and 4 Data Columns, which is supported by the previous subsection.</p>
# \begin{equation}
# (Row , Column)
# \end{equation}

# %% [markdown]
# <hr/>
# <h3>2.4.3 Description of Data</h3>

# %% [markdown]
# <p>In the cell below, I will execute an operation which will describe the Numerical Data of the dataset The information displayed will include important information, especially mean (average) which can be used as a strategy to Impute Missing Data if there are any.</p>

# %%
# ----------- Describing DataFrame ----------- #
df.describe().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_bfaa2_row0_col0, #T_bfaa2_row0_col1, #T_bfaa2_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bfaa2_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_bfaa2_row1_col1, #T_bfaa2_row1_col2, #T_bfaa2_row5_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_bfaa2_row2_col0, #T_bfaa2_row3_col1, #T_bfaa2_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bfaa2_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_bfaa2_row2_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_bfaa2_row3_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_bfaa2_row4_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_bfaa2_row4_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_bfaa2_row4_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_bfaa2_row5_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_bfaa2_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_bfaa2_row6_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_bfaa2_row6_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_bfaa2_row6_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_bfaa2_row7_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_bfaa2_row7_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_bfaa2_row7_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bfaa2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfaa2_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_bfaa2_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_bfaa2_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfaa2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_bfaa2_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_bfaa2_row0_col1" class="data row0 col1" >200.000000</td>
#       <td id="T_bfaa2_row0_col2" class="data row0 col2" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_bfaa2_row1_col0" class="data row1 col0" >38.850000</td>
#       <td id="T_bfaa2_row1_col1" class="data row1 col1" >60.560000</td>
#       <td id="T_bfaa2_row1_col2" class="data row1 col2" >50.200000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_bfaa2_row2_col0" class="data row2 col0" >13.969007</td>
#       <td id="T_bfaa2_row2_col1" class="data row2 col1" >26.264721</td>
#       <td id="T_bfaa2_row2_col2" class="data row2 col2" >25.823522</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_bfaa2_row3_col0" class="data row3 col0" >18.000000</td>
#       <td id="T_bfaa2_row3_col1" class="data row3 col1" >15.000000</td>
#       <td id="T_bfaa2_row3_col2" class="data row3 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_bfaa2_row4_col0" class="data row4 col0" >28.750000</td>
#       <td id="T_bfaa2_row4_col1" class="data row4 col1" >41.500000</td>
#       <td id="T_bfaa2_row4_col2" class="data row4 col2" >34.750000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_bfaa2_row5_col0" class="data row5 col0" >36.000000</td>
#       <td id="T_bfaa2_row5_col1" class="data row5 col1" >61.500000</td>
#       <td id="T_bfaa2_row5_col2" class="data row5 col2" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_bfaa2_row6_col0" class="data row6 col0" >49.000000</td>
#       <td id="T_bfaa2_row6_col1" class="data row6 col1" >78.000000</td>
#       <td id="T_bfaa2_row6_col2" class="data row6 col2" >73.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_bfaa2_row7_col0" class="data row7 col0" >70.000000</td>
#       <td id="T_bfaa2_row7_col1" class="data row7 col1" >137.000000</td>
#       <td id="T_bfaa2_row7_col2" class="data row7 col2" >99.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the dataframe above, I am able to see the mean of all three Numerical Data and also see the wide range of Customer the business receives such as a large difference in the Age Demographic and Customers of varying Social-Economic Status and their Money Power.</p>

# %% [markdown]
# <hr/>
# <h1>3. Data Cleaning</h1>

# %% [markdown]
# <p>In this section, I will be conducting Data Cleaning. This process is extremely important as without this process, a model cannot be trained under any circumstances due to the data not being properly cleaned. Throughout this section, I will be checking, imputing and verifying missing datas for my datasets.</p>

# %% [markdown]
# <hr/>
# <h2>3.1 Checking For Missing Data</h2>

# %% [markdown]
# <p>In the cell below, I will be checking for the total amount of missing data value per category. By checking for the sum of the missing data, I can later compare it to the sum of missing data after I imputed the missing data.</p>

# %%
# ----------- Placing Missing Values Of df Into A Dataframe ----------- #
missingData = pd.DataFrame({'Missing Values': df.isnull().sum().values}, index = df.columns)

# ----------- Function For Colour Coding ----------- #
def colour_code(values):
    return 'background-color: green' if values == 0 else 'background-color: red'

# ----------- Calling Function For Colour Coding ----------- #
missingData = missingData.style.map(colour_code, subset = ['Missing Values'])

# ----------- Displaying Missing Values ----------- #
missingData
# Out:
# <style type="text/css">
# #T_95b75_row0_col0, #T_95b75_row1_col0, #T_95b75_row2_col0, #T_95b75_row3_col0 {
#   background-color: green;
# }
# </style>
# <table id="T_95b75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95b75_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95b75_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_95b75_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95b75_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_95b75_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95b75_level0_row2" class="row_heading level0 row2" >Income (k$)</th>
#       <td id="T_95b75_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95b75_level0_row3" class="row_heading level0 row3" >How Much They Spend</th>
#       <td id="T_95b75_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output above, I am able to verify that there is no missing data within the dataset and that there is no need to impute any missing data for any of the Data Column. This allows me to subsequently proceed to check for Duplicated Data within the dataset.</p>

# %% [markdown]
# <hr/>
# <h2>3.2 Checking For Duplicated Data</h2>

# %% [markdown]
# <p>To address Duplicated Data, I have to verify if there are duplicated data in the first place. In the cell below, I will be checking for duplicated data and based on the output, one of the two action plan will occur.</p>
# <br/>
# <span style="color:red"><p><strong><u>Duplicated Data Identified</u></strong></p></span>
# <ul>
#     <li>Proceed to remove the duplicated data.</li>
# </ul>
# <span style="color:green"><p><strong><u>No Duplicated Data Identified</u></strong></p></span>
# <ul>
#     <li>Proceed with next sub-section on Fixing Data Types.</li>
# </ul>
# <br/>
# <p>With the action plan listed above, I will be proceeding to check for duplicated data.</p>

# %%
# ----------- Calculate Total Duplicated Rows ----------- #
duplicatesCount = df.duplicated().sum()

# ----------- Create DataFrame to Store Result ----------- #
duplicateSummary = pd.DataFrame({'Count': [duplicatesCount]}, index = ['Duplicated Rows'])

# ----------- Function for Colour Coding ----------- #
def colour_code(val):
    if val > 0:
        return 'background-color: red; color: white'
    else:
        return 'background-color: green; color: white'

# ----------- Apply Colour Coding to the 'Count' Column ----------- #
duplicateSummary = duplicateSummary.style.map(colour_code, subset=['Count'])

# ----------- Display the Result ----------- #
duplicateSummary
# Out:
# <style type="text/css">
# #T_f186f_row0_col0 {
#   background-color: green;
#   color: white;
# }
# </style>
# <table id="T_f186f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f186f_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f186f_level0_row0" class="row_heading level0 row0" >Duplicated Rows</th>
#       <td id="T_f186f_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the Dataframe above, I am able to verify that there are <span style="color:green"><strong><u>No Duplicated Data Identified</u></strong></span>. Therefore, I am able to proceed to Feature Engineering for the Dataset.</p>

# %% [markdown]
# <hr/>
# <h1>4. Feature Engineering</h1>

# %% [markdown]
# <p>In this section of Feature Engineering, I will be doing many operations such as creating dummy variables, removing outliers and creating new features. Feature Engineering plays an important role in ensuring my model can be trained with the dataset and also ensures that the accuracy of my model is not compromised in any case especially if it is due to the presence of outliers. However, many operation for Feature Engineering will be up to my discretion due to there not being a clear answer in many of the decisions which I need to make.</p>

# %% [markdown]
# <hr/>
# <h2>4.1 Dummy Variable for Gender</h2>

# %% [markdown]
# <p>I will be creating a Dummy Variable for the categorical data 'Gender'. This is because Clustering Models are not able to take in Categorical Data. Therefore, it will be much easier if I directly change the different Gender into Dummy Variable. I will also be using the 'One-Hot' method where instead of creating 2 columns, I will only be creating 1 columns to ensure the efficiency of training the models. The representation of the Dummy Variable is as follows,</p>
# <br/>
# <p><strong><u>Male</u></strong></p>
# <ul>
#     <li>Male = 1</li>
# </ul>
#
# <p><strong><u>Female</u></strong></p>
# <ul>
#     <li>Male = 0</li>
# </ul>
# <br/>
# <p>With the representation of the Dummy Variable listed out, I will proceed to execute the Dummy Variable Operation in the cell below.</p>

# %%
# ------------ Dummy Variable Creation Using One-Hot Method ------------ #
df = pd.get_dummies(df, columns = ['Gender'], prefix = 'Gender', drop_first = True, dtype = int)

# ------------ Displaying DataFrame ----------- #
df.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_30b5f_row0_col0, #T_30b5f_row0_col1, #T_30b5f_row1_col1, #T_30b5f_row2_col2, #T_30b5f_row2_col3, #T_30b5f_row3_col3, #T_30b5f_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_30b5f_row0_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_30b5f_row0_col3, #T_30b5f_row1_col2, #T_30b5f_row1_col3, #T_30b5f_row4_col0, #T_30b5f_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_30b5f_row1_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_30b5f_row2_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_30b5f_row2_col1, #T_30b5f_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_30b5f_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_30b5f_row3_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_30b5f_row4_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# </style>
# <table id="T_30b5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30b5f_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_30b5f_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_30b5f_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_30b5f_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30b5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30b5f_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_30b5f_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_30b5f_row0_col2" class="data row0 col2" >39</td>
#       <td id="T_30b5f_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30b5f_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_30b5f_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_30b5f_row1_col2" class="data row1 col2" >81</td>
#       <td id="T_30b5f_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30b5f_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_30b5f_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_30b5f_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_30b5f_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30b5f_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_30b5f_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_30b5f_row3_col2" class="data row3 col2" >77</td>
#       <td id="T_30b5f_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_30b5f_row4_col0" class="data row4 col0" >31</td>
#       <td id="T_30b5f_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_30b5f_row4_col2" class="data row4 col2" >40</td>
#       <td id="T_30b5f_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the DataFrame output produced by the cell above, I can verify that the 'Gender' data column which was previously there has been removed and now there is 1 new Data Column called 'Gender_Male'. I am also able to verify that there are a mixture of combinattions which further support my inference that the 'Gender' data column have been successfully converted to a Dummy Variable. Therefore, with strong evidence supporting my assumption of the successful creation of Dummy Variable in place of 'Gender' data column, I will now move on to the next feature engineering that I will be executing.</p>

# %% [markdown]
# <hr/>
# <h2>4.2 Identifying Outliers</h2>

# %% [markdown]
# <p>In this sub-section, I will be Identifying Outliers using visualisations. Subsequently, I will need to address the Outliers accordingly on a case by case basis as some Outliers may not neccessarily have a negative effect. Outliers can cause a model to have lower accuracy level due to there being unrealistic datas which can skew the results, affecting the model's ability to cluster properly. The easiest and most used method to visualise outlier is using a Boxplot. A Boxplot will contain a few important parts such as the minimum, maximum, lower quartile, second quartile (median), and upper quartile. With all these parts present, I am able to perform and visualise important calculations such as the Inter-Quartile Range which will assist us in establishing the lower and upper fence should there be any Outliers. An Outlier will be flagged if it is below the Minimum or above the Maximum. Through the Boxplot, I am also able to visualise how many Outliers is present within a Numerical Category. As 'Gender' is represented by Dummy Variable, it will be excluded from this operation. The action plan for this section has been listed below.</p>
# <br/>
# <span style="color:red"><p><strong><u>Outliers Identified</u></strong></p></span>
# <ul>
#     <li>Proceed to determine the best course of action to undertake so as to address the Outlier.</li>
#     <li>Execute the planned out action in the next section.</li>
# </ul>
# <span style="color:green"><p><strong><u>No Outliers Identified</u></strong></p></span>
# <ul>
#     <li>Proceed to the next sub-section.</li>
# </ul>
# <br/>
# <p>With the action plan laid out, we will proceed to identify the Outliers in all Numerical Data.</p>

# %%
# ---------- Filter Numeric Columns Only ---------- #
numeric_columns = df.select_dtypes(include=['float64', 'int32', 'int64']).columns

# ---------- Plot Boxplots For All Numeric Columns ---------- #
plt.figure(figsize=(10, 11))
sns.boxplot(data=df[numeric_columns], orient='h', palette='coolwarm')
plt.title('Outliers Identification', fontsize=16)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.show()

# %% [markdown]
# <p>With reference to the output of the Boxplot above, I am able to determine that there is indeed an outlier for income where there is a data point at around 140k\$. Therefore, the result of the identification is concluded as <span style="color:red"><strong><u>Outliers Identified</u></strong></span>. The best course of action has been listed below.</p>
# <br/>
# <p><strong><u>Income (k\$)</u></strong></p>
# <ul>
#     <li>Course of Action: IQR Method</li>
#     <li>Reason: Due to Income (k\$) being skewed to the right.</li>
# </ul>
# <br/>
# <p>With the best Course of Action listed out, I will proceed to remove the Outlier from the Dataset.</p>

# %% [markdown]
# <hr/>
# <h2>4.3 Addressing Outliers Using IQR Method</h2>

# %% [markdown]
# <p>The IQR Method requires the establishment of a Upper Fence and Lower Fence such that any data which are above the Upper Fence will be deemed invalid and illegitimate and will be removed whereas any data which are below the Lower Fence will be deemed likewise and removed. In the cells below, I will be removing Outliers using the IQR Method.</p>
#
# $$\text{IQR} = \text{Q3} - \text{Q1}$$
# $$\text{Lower Fence} = \text{Q1} - 1.5 \times \text{IQR}$$
# $$\text{Upper Fence} = \text{Q3} + 1.5 \times \text{IQR}$$
# <br/>
# <p>With the formulas listed, I will proceed with identifying and removing the Outliers.</p>

# %%
# ---------- Columns With Outliers ---------- #
columns = [
    'Income (k$)'
]

# ---------- Function For Upper And Lower Bounds Calculations ---------- #
def calculate_bounds(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

# ---------- Flagging Of Outliers ---------- #
for col in columns:
    # Calculate bounds for the current column
    lower_bound, upper_bound = calculate_bounds(df[col])
    
    # Create a mask for outliers, ignoring NaN values
    df[f'Outlier_{col}'] = ((df[col] < lower_bound) | (df[col] > upper_bound)) & ~df[col].isna()

# ----------- Removal Of Outliers ---------- #
for col in columns:
    # Retain NaN values and remove only rows flagged as outliers
    df = df[(df[f'Outlier_{col}'] == False) | (df[col].isna())]

# ---------- Removal Of Data Column Used For Calculation ---------- #
outlier_cols = [f'Outlier_{col}' for col in columns]
df.drop(outlier_cols, axis=1, inplace=True)

# ---------- Filter Numeric Columns Only ---------- #
numeric_columns = df.select_dtypes(include=['float64', 'int32', 'int64']).columns

# ---------- Plot Boxplots for All Numeric Columns ---------- #
plt.figure(figsize=(10, 11))
sns.boxplot(data=df[numeric_columns], orient='h', palette='coolwarm')
plt.title('Outliers Identification', fontsize=16)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.show()

# %% [markdown]
# <p>With reference to the output of the Boxplot above, I am able to verify that the Outlier have been successfully removed and the Upper and Lower Fence have been successfully established. As there are no more Outliers remaining, I will proceed with Data Exploration of the new DataFrame.</p>

# %% [markdown]
# <hr/>
# <h2>4.4 Data Exploration of Updated DataFrame</h2>

# %% [markdown]
# <p>In this sub-section, I will be exploring the new DataFrame which have been ammended in the previous sub-section as the Outliers have been addressed. Thoughout this sub-section, I will mainly focus on what has changed compared to before the removal of some Outliers.</p>

# %% [markdown]
# <hr/>
# <h3>4.4.1 Shape of Updated DataFrame</h3>

# %% [markdown]
# <p>I will be running the shape method to view how many data rows are remaining as compared to before removing some of the Outliers. This will give me insights on what is the scale of the new data that I am working with.</p>

# %%
# ----------- df's Shape ----------- #
shape_data = {'Attribute': ['Rows', 'Columns'], 'Count': list(df.shape)}

# ----------- Putting Shape Into DataFrame ----------- #
df_shape = pd.DataFrame(shape_data)

# ----------- Displaying DataFrame ----------- #
df_shape.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_b3a78_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b3a78_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b3a78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3a78_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_b3a78_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3a78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3a78_row0_col0" class="data row0 col0" >Rows</td>
#       <td id="T_b3a78_row0_col1" class="data row0 col1" >198</td>
#     </tr>
#     <tr>
#       <th id="T_b3a78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3a78_row1_col0" class="data row1 col0" >Columns</td>
#       <td id="T_b3a78_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame, I am able to confirm that there was only a total of 2 Outliers which was removed using the IQR Method. This means that I did not lose much data as compared to the original 200 Data Rows.</p>

# %% [markdown]
# <hr/>
# <h3>4.4.2 Description of Updated DataFrame</h3>

# %% [markdown]
# <p>The last operation which I will perform on the new data is using the describe function. This will describe all the numerical data's information such as mean, standard deviation, etc. As all the data columns are now numerical, I should be able to see all the data column present.</p>

# %%
# ----------- Describing DataFrame ----------- #
df.describe().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_b88ee_row0_col0, #T_b88ee_row0_col1, #T_b88ee_row0_col2, #T_b88ee_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b88ee_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_b88ee_row1_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_b88ee_row1_col2, #T_b88ee_row5_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b88ee_row1_col3, #T_b88ee_row2_col0, #T_b88ee_row2_col3, #T_b88ee_row3_col1, #T_b88ee_row3_col2, #T_b88ee_row3_col3, #T_b88ee_row4_col3, #T_b88ee_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b88ee_row2_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b88ee_row2_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b88ee_row3_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b88ee_row4_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b88ee_row4_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b88ee_row4_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_b88ee_row5_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_b88ee_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b88ee_row6_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b88ee_row6_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b88ee_row6_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_b88ee_row6_col3, #T_b88ee_row7_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b88ee_row7_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b88ee_row7_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_b88ee_row7_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b88ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b88ee_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_b88ee_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_b88ee_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_b88ee_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b88ee_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b88ee_row0_col0" class="data row0 col0" >198.000000</td>
#       <td id="T_b88ee_row0_col1" class="data row0 col1" >198.000000</td>
#       <td id="T_b88ee_row0_col2" class="data row0 col2" >198.000000</td>
#       <td id="T_b88ee_row0_col3" class="data row0 col3" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b88ee_row1_col0" class="data row1 col0" >38.929293</td>
#       <td id="T_b88ee_row1_col1" class="data row1 col1" >59.787879</td>
#       <td id="T_b88ee_row1_col2" class="data row1 col2" >50.196970</td>
#       <td id="T_b88ee_row1_col3" class="data row1 col3" >0.434343</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b88ee_row2_col0" class="data row2 col0" >14.016852</td>
#       <td id="T_b88ee_row2_col1" class="data row2 col1" >25.237259</td>
#       <td id="T_b88ee_row2_col2" class="data row2 col2" >25.746846</td>
#       <td id="T_b88ee_row2_col3" class="data row2 col3" >0.496927</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b88ee_row3_col0" class="data row3 col0" >18.000000</td>
#       <td id="T_b88ee_row3_col1" class="data row3 col1" >15.000000</td>
#       <td id="T_b88ee_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_b88ee_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b88ee_row4_col0" class="data row4 col0" >28.250000</td>
#       <td id="T_b88ee_row4_col1" class="data row4 col1" >40.500000</td>
#       <td id="T_b88ee_row4_col2" class="data row4 col2" >35.000000</td>
#       <td id="T_b88ee_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_b88ee_row5_col0" class="data row5 col0" >36.000000</td>
#       <td id="T_b88ee_row5_col1" class="data row5 col1" >61.000000</td>
#       <td id="T_b88ee_row5_col2" class="data row5 col2" >50.000000</td>
#       <td id="T_b88ee_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_b88ee_row6_col0" class="data row6 col0" >49.000000</td>
#       <td id="T_b88ee_row6_col1" class="data row6 col1" >77.750000</td>
#       <td id="T_b88ee_row6_col2" class="data row6 col2" >72.750000</td>
#       <td id="T_b88ee_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_b88ee_row7_col0" class="data row7 col0" >70.000000</td>
#       <td id="T_b88ee_row7_col1" class="data row7 col1" >126.000000</td>
#       <td id="T_b88ee_row7_col2" class="data row7 col2" >99.000000</td>
#       <td id="T_b88ee_row7_col3" class="data row7 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the DataFrame output by the cell above, I am able to verify that all the data columns are present. However, the numerical information should be ignored for 'Gender_Male'. This is because, despite them being Numerical Data, it is still a dummy variable. Therefore, the numerical information does not tell us any information about these data columns since the data is either '1' or '0'. However, we are able to see that the 'Income (k\$)' has a new max of 126 which indicated that the Outliers have caused some changes within the Data Column.</p>
