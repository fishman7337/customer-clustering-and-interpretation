# %% [markdown]
# <h1>Customer Segmentation</h1>
#
# <hr/>
#
# <p>Name: <strong>Goh Kun Ming</strong><br/></p>
# <p>Admin Number: <strong>P2415691</strong><br/></p>
# <p>Class: <strong>DAAA/FT/1B/02</strong><br/></p>
#
# <hr/>
#
# <h1>Assessment Objective</h1>
#
# <hr/>
#
# <p>The assessment objective is to segregate customers into various clusters so as to improve customer service through personalisation so as to improve customer satisfaction.</p><br/>
#
# <hr/>
#
# <h1>Background Information</h1>
#
# <hr/>
#
# <p>Customer segmentation helps businesses understand their customers better by grouping them into clusters with similar characteristics. This creates more opportunity and insights on how to manage resources to cater to different type of customers. As customer reviews can positively or negatively affect the operation of a business especially in a digitalised world where Google Reviews are often seen by potential customers. Therefore, it is of the utmost importance to segregate customers based on their profile such as Gender, Age, Income and Spendings.</p>

# %% [markdown]
# <hr/>
# <h1>1. Importing of Modules</h1>

# %% [markdown]
# <p>Within this section, I will be executing importing operations so as to import different libaries and modules for my project. The import of libaries and modules is necessary and required for the Unsupervised Machine Learning. Each libary or module will serve a different function but will all work together towards the same objective which is to produce an effective Unsupervised Machine Learning Algorithm that can be deployed with high reliability.</p>

# %% [markdown]
# <hr/>
# <h2>1.1 Importing of Data Analytics Modules</h2>

# %% [markdown]
# <p>In order to conduct Data Analysis on my dataset, I will require 2 main libaries which are 'NumPy' and 'Pandas'. As shown in the cell below, 'NumPy' will hold the alias of 'np' whereas 'Pandas' will hold the alias 'pd'. After importing the libaries, I will be able perform Data Analysis on my datasets.</p>

# %%
# ------------- Importing NumPy As Alias 'np' ------------- #
import numpy as np

# ------------- Importing Pandas As Alias 'pd' ------------- #
import pandas as pd

# %% [markdown]
# <hr/>
# <h2>1.2 Importing of Graph Plotting Modules</h2>

# %% [markdown]
# <p>In order to conduct Data Visualisation on my dataset, I will require 1 main library which is 'Matplotlib' and 1 supporting library which is 'Seaborn'. I will also be importing 'Plotly'. As shown in the cell below, 'Matplotlib' will hold the alias 'plt', 'Seaborn' will hold the alias 'sns' and 'Plotly' will hold the alias 'px'. After importing the libraries, I will be able to perfrom Data Visualisations on my dataset and my model.</p>

# %%
# ------------- Importing Matplot As Alias 'plt' ------------- #
import matplotlib.pyplot as plt

# ------------- Importing Seaborn As Alias 'sns' ------------- #
import seaborn as sns

# ------------- Importing Plotly As Alias 'px' ------------- #
import plotly.express as px

# %% [markdown]
# <hr/>
# <h2>1.3 Importing of Scikit-learn Data Processing Modules</h2>

# %% [markdown]
# <p>In order to conduct Data Processing and Hyperparameter Tuning, I will require multiple modules such as 'StandardScaler'. I will also be importing model hyperparameter improvement modules such as 'RandomizedSearchCV' and 'GridSearchCV' alongside the other modules. After importing the modules as shown in the cell below, I am able to conduct Data Processing and Hyperparameter Tuning.</p>

# %%
# ------------- Importing SimpleImputer From Scikit-learn ------------- #
from sklearn.impute import SimpleImputer

# ------------- Importing GridSearchCV From Scikit-learn ------------- #
from sklearn.model_selection import GridSearchCV

# ------------- Importing RandomizedSearchCV From Scikit-learn ------------- #
from sklearn.model_selection import RandomizedSearchCV
    
# ------------- Importing t-Distributed Stochastic Neighbour Embedding From Scikit-learn ------------- #
from sklearn.manifold import TSNE

# ------------- Importing Principal Component Analysis From Scikit-learn ------------- #
from sklearn.decomposition import PCA

# ------------- Importing StandardScaler From Scikit-learn ------------- #
from sklearn.preprocessing import StandardScaler

# ------------- Importing LabelEncoder From Scikit-learn ------------- #
from sklearn.preprocessing import LabelEncoder

# ------------- Importing OneHotEncoder From Scikit-learn ------------- #
from sklearn.preprocessing import OneHotEncoder

# ------------- Importing MinMaxScaler From Scikit-learn ------------- #
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# <hr/>
# <h2>1.4 Importing of Scikit-learn Clustering Models</h2>

# %% [markdown]
# <p>In this sub-section, I will be importing various Clustering Models that will be used and also the respective measurement of ideal number of clusters which will subsequently be used as a parameter for the clustering. The models and metrics are imported in the cell below.</p>

# %%
# ------------- Importing NearestNeighbors From Scikit-learn ------------- #
from sklearn.neighbors import NearestNeighbors

# ------------- Importing KMeans From Scikit-learn ------------- #
from sklearn.cluster import KMeans

# ------------- Importing AgglomerativeClustering From Scikit-learn ------------- #
from sklearn.cluster import AgglomerativeClustering

# -------------Importing DBSCAN From Scikit-learn ------------- #
from sklearn.cluster import DBSCAN

# ------------- Importing Decision Tree From Scikit-learn ------------- #
from sklearn.tree import DecisionTreeClassifier

# ------------- Importing plot_tree From Scikit-learn ------------- #
from sklearn.tree import plot_tree

# ------------- Importing Birch From Scikit-learn ------------- #
from sklearn.cluster import Birch

# ------------- Importing MeanShift From Scikit-learn ------------- #
from sklearn.cluster import MeanShift

# ------------- Importing SpectralClustering From Scikit-learn ------------- #
from sklearn.cluster import SpectralClustering

# ------------- Importing silhouette_score From Scikit-learn ------------- #
from sklearn.metrics import silhouette_score

# ------------- Importing davies_bouldin_score From Scikit-learn ------------- #
from sklearn.metrics import davies_bouldin_score

# ------------- Importing ParameterGrid From Scikit-learn ------------- #
from sklearn.model_selection import ParameterGrid

# ------------- Importing calinski_harabasz_score From Scikit-learn ------------- #
from sklearn.metrics import calinski_harabasz_score

# ------------- Importing silhouette_samples From Scikit-learn ------------- #
from sklearn.metrics import silhouette_samples

# ------------- Importing adjusted_rand_score From Scikit-learn ------------- #
from sklearn.metrics import adjusted_rand_score

# ------------- Importing Hierarchy From Scipy ------------- #
import scipy.cluster.hierarchy as sch

# ------------- Importing normalized_mutual_info_score From Scikit-learn ------------- #
from sklearn.metrics import normalized_mutual_info_score

# ------------- Importing homogeneity_completeness_v_measure From Scikit-learn ------------- #
from sklearn.metrics import homogeneity_completeness_v_measure

# %% [markdown]
# <hr/>
# <h2>1.5 Importing Warnings & Ignoring Warnings</h2>

# %% [markdown]
# <p>In order to ignore warnings (e.g. future warnings), I will be importing 'warnings' so that I am able to filter it and subsequently ignore it. The ignoring of warnings will not affect the performance or the effectiveness of my project as the warning is only applicable in the future.</p>

# %%
# Importing Warnings And Filtering Warnings ------------- #
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <hr/>
# <h2>1.6 Importing Joblib & OS</h2>

# %% [markdown]
# <p>In order to save my model for deployment, I will be importing 'joblib' and 'os' so that I will be able to save my model to a specific folder within my CA2 project folder.</p>

# %%
# ------------- Importing Joblib ------------- #
import joblib

# ------------- Importing os ------------- #
import os

# %% [markdown]
# <hr/>
# <h1>2. Data Analysis</h1>

# %% [markdown]
# <p>In this section, I will be conducting simple Data Analysis to understand the dataset provided at a deeper level. By conducting Data Analysis, I will be able to evaluate what I need to do and subsequently, path the way for other operations that need to be conducted. This section is extremely important as without doing a proper Data Analysis, I will not be able to train the Unsupervised Model effectively and may even encounter errors within the datasets due to poor planning that occured due to a poor Data Analysis conducted by me.</p>

# %% [markdown]
# <hr/>
# <h2>2.1 Importing of CSV File</h2>

# %% [markdown]
# <p>Before performing Data Analysis, I will need to import the CSV file that has been provided to me. By performing the operation as shown in the cell below, I have also directly placed the CSV File into a dataframe which allows me to perform various operation on it afterwards.</p>

# %%
# ----------- Importing of CSV File ---------- #
df = pd.read_csv("CA2-Dataset/CA2-Customer-Data.csv", sep = ",")

# ----------- Execution Confirmation ----------- #
print("CSV File Successfully Imported")
# Out:
# CSV File Successfully Imported

# %% [markdown]
# <p>As shown in the cell above, the text 'CSV File Successfully Imported' shows that the previous line of code which is meant to import the CSV File has been successfully executed and that 'df' now holds the dataframe that is related to the CSV File.</p>

# %% [markdown]
# <hr/>
# <h2>2.2 Reading of CSV File</h2>

# %% [markdown]
# <p>After successfully importing the CSV File as 'df', I will be taking a look at the first 10 data rows of the dataframe. I will then evaluate what needs to be done regarding the dataset that has been provided.</p>

# %%
# ------------- Displaying DataFrame ----------- #
df.head(10).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_460a7_row0_col0, #T_460a7_row0_col2, #T_460a7_row0_col3, #T_460a7_row1_col3, #T_460a7_row8_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_460a7_row0_col4 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_460a7_row1_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_460a7_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_460a7_row1_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_460a7_row2_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_460a7_row2_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_460a7_row2_col3, #T_460a7_row3_col3 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_460a7_row2_col4, #T_460a7_row6_col4 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_460a7_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_460a7_row3_col2, #T_460a7_row7_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_460a7_row3_col4 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_460a7_row4_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_460a7_row4_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_460a7_row4_col3, #T_460a7_row5_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_460a7_row4_col4 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_460a7_row5_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_460a7_row5_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_460a7_row5_col4 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_460a7_row6_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_460a7_row6_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_460a7_row6_col3, #T_460a7_row7_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_460a7_row7_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_460a7_row7_col4, #T_460a7_row8_col2, #T_460a7_row8_col3, #T_460a7_row9_col0, #T_460a7_row9_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_460a7_row8_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_460a7_row9_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_460a7_row9_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_460a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_460a7_level0_col0" class="col_heading level0 col0" >CustomerID</th>
#       <th id="T_460a7_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_460a7_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_460a7_level0_col3" class="col_heading level0 col3" >Income (k$)</th>
#       <th id="T_460a7_level0_col4" class="col_heading level0 col4" >How Much They Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_460a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_460a7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_460a7_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_460a7_row0_col2" class="data row0 col2" >19</td>
#       <td id="T_460a7_row0_col3" class="data row0 col3" >15</td>
#       <td id="T_460a7_row0_col4" class="data row0 col4" >39</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_460a7_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_460a7_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_460a7_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_460a7_row1_col3" class="data row1 col3" >15</td>
#       <td id="T_460a7_row1_col4" class="data row1 col4" >81</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_460a7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_460a7_row2_col1" class="data row2 col1" >Female</td>
#       <td id="T_460a7_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_460a7_row2_col3" class="data row2 col3" >16</td>
#       <td id="T_460a7_row2_col4" class="data row2 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_460a7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_460a7_row3_col1" class="data row3 col1" >Female</td>
#       <td id="T_460a7_row3_col2" class="data row3 col2" >23</td>
#       <td id="T_460a7_row3_col3" class="data row3 col3" >16</td>
#       <td id="T_460a7_row3_col4" class="data row3 col4" >77</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_460a7_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_460a7_row4_col1" class="data row4 col1" >Female</td>
#       <td id="T_460a7_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_460a7_row4_col3" class="data row4 col3" >17</td>
#       <td id="T_460a7_row4_col4" class="data row4 col4" >40</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_460a7_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_460a7_row5_col1" class="data row5 col1" >Female</td>
#       <td id="T_460a7_row5_col2" class="data row5 col2" >22</td>
#       <td id="T_460a7_row5_col3" class="data row5 col3" >17</td>
#       <td id="T_460a7_row5_col4" class="data row5 col4" >76</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_460a7_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_460a7_row6_col1" class="data row6 col1" >Female</td>
#       <td id="T_460a7_row6_col2" class="data row6 col2" >35</td>
#       <td id="T_460a7_row6_col3" class="data row6 col3" >18</td>
#       <td id="T_460a7_row6_col4" class="data row6 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_460a7_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_460a7_row7_col1" class="data row7 col1" >Female</td>
#       <td id="T_460a7_row7_col2" class="data row7 col2" >23</td>
#       <td id="T_460a7_row7_col3" class="data row7 col3" >18</td>
#       <td id="T_460a7_row7_col4" class="data row7 col4" >94</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_460a7_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_460a7_row8_col1" class="data row8 col1" >Male</td>
#       <td id="T_460a7_row8_col2" class="data row8 col2" >64</td>
#       <td id="T_460a7_row8_col3" class="data row8 col3" >19</td>
#       <td id="T_460a7_row8_col4" class="data row8 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_460a7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_460a7_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_460a7_row9_col1" class="data row9 col1" >Female</td>
#       <td id="T_460a7_row9_col2" class="data row9 col2" >30</td>
#       <td id="T_460a7_row9_col3" class="data row9 col3" >19</td>
#       <td id="T_460a7_row9_col4" class="data row9 col4" >72</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to see that there is a total of 5 Data Column, 4 of which are Numerical Data and 1 of which is a Categorical Data. The Categorical Data needs to be converted into dummy variable but the standard method of One-Hot Encoding may not be suitable due to the requirement of Numerical Data needing to be Scaled so as to not be deemed redundant by the Clustering Model. The initial 10 rows also shows no missing data. However, this has to be fact checked later on.</p>

# %% [markdown]
# <hr/>
# <h3>2.2.1 Interpretation of CSV File's Data Column</h3>

# %% [markdown]
# <p><strong><u>CustomerID</u></strong></p>
# <ul>
#     <li>Unique to each Customer.</li>
#     <li>Does not assist in clustering. Instead, it might reduce the accuracy of the Clustering.</li>
#     <li>Does not help in improving Customer Service of Businesses.</li>
#     <li>Will not be used as a Feature due to lack of use.</li>
# </ul>
#
# <p><strong><u>Gender</u></strong></p>
# <ul>
#     <li>Gender of each Customer.</li>
#     <li>Needs to be converted to dummy variable due to Clustering Models only accepting Numerical Data.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Research shows Males to be more Functional and Outcome-oriented whereas Females focus more on Actual Service and Emotional Outcomes.</li>
#     <li>Businesses should train staff based on how to treat customers of different gender and ensuring it alligns with their satisfaction.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>
#
# <p><strong><u>Age</u></strong></p>
# <ul>
#     <li>Age of each Customer.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Research shows Customers of Older Demographics prefers Quality Face-to-Face Customer Service whereas Customers of Younger Demographics has higher expectations such as a Website, Social Media and Loyality Program.</li>
#     <li>Businesses should ensure that their Target Age Group's satisfaction is placed as the highest priority. For example, if the Target Age Group is Teenagers, Websites and Social Medias should be maintained frequently whereas if the Target Age Group is Adults, more staff should be on-site to assist them.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>
#
# <p><strong><u>Income (k$)</u></strong></p>
# <ul>
#     <li>Annual Income of each Customer.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Customers who have Higher Income may be More Demanding and Less Sensitive to Prices whereas the opposite is true for Customers with Lower Income.</li>
#     <li>Businesses should train their staff on the available inventory items' prices so as to cater to the budget of different Customers, thus creating Higher Overall Customer Satisfaction.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>
#
# <p><strong><u>How Much They Spend</u></strong></p>
# <ul>
#     <li>The Amount of Money each Customer spend.</li>
#     <li>Potentially contributes to how an individual prefers to be treated which affects how Customer Service should be handled.</li>
#     <li>Customers who haveHigher Spendingse may be More Demanding and Less Sensitive to Prices whereas the opposite is true for Customers with LowerSpending..</li>
#     <li>Businesses should train their staff to treat all Customers with Professionalism and without Discrimination so as to Increase Overall Customer Satisfactionn.</li>
#     <li>Will be used as a Feature in the Dataset for Data Visualisation and Clustering.</li>
# </ul>

# %% [markdown]
# <hr/>
# <h2>2.3 Dropping Exclusive Data</h2>

# %% [markdown]
# <p>As observed previously, there are exclusive data that are present within the dataset. These data columns that contain the exclusive data will be dropped as they contribute nothing towards the Clustering and only serves as an Unique Identifier for all the Customers. Thus, I have come to the conclusion that dropping these exclusive data columns is neccessary.</p>

# %%
# ------------ Selecting Non-Exclusive Data Columns ---------- #
df = df.iloc[:, 1:9]

# ---------- Displaying DataFrame ------------ #
df.head(10).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_6dbed_row0_col1, #T_6dbed_row0_col2, #T_6dbed_row1_col2, #T_6dbed_row8_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6dbed_row0_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_6dbed_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6dbed_row1_col3 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_6dbed_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_6dbed_row2_col2, #T_6dbed_row3_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_6dbed_row2_col3, #T_6dbed_row6_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_6dbed_row3_col1, #T_6dbed_row7_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_6dbed_row3_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_6dbed_row4_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_6dbed_row4_col2, #T_6dbed_row5_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_6dbed_row4_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_6dbed_row5_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_6dbed_row5_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_6dbed_row6_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_6dbed_row6_col2, #T_6dbed_row7_col2 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_6dbed_row7_col3, #T_6dbed_row8_col1, #T_6dbed_row8_col2, #T_6dbed_row9_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6dbed_row9_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_6dbed_row9_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6dbed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dbed_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_6dbed_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_6dbed_level0_col2" class="col_heading level0 col2" >Income (k$)</th>
#       <th id="T_6dbed_level0_col3" class="col_heading level0 col3" >How Much They Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dbed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dbed_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_6dbed_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_6dbed_row0_col2" class="data row0 col2" >15</td>
#       <td id="T_6dbed_row0_col3" class="data row0 col3" >39</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6dbed_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_6dbed_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_6dbed_row1_col2" class="data row1 col2" >15</td>
#       <td id="T_6dbed_row1_col3" class="data row1 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6dbed_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_6dbed_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_6dbed_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_6dbed_row2_col3" class="data row2 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6dbed_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_6dbed_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_6dbed_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_6dbed_row3_col3" class="data row3 col3" >77</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6dbed_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_6dbed_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_6dbed_row4_col2" class="data row4 col2" >17</td>
#       <td id="T_6dbed_row4_col3" class="data row4 col3" >40</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6dbed_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_6dbed_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_6dbed_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_6dbed_row5_col3" class="data row5 col3" >76</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6dbed_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_6dbed_row6_col1" class="data row6 col1" >35</td>
#       <td id="T_6dbed_row6_col2" class="data row6 col2" >18</td>
#       <td id="T_6dbed_row6_col3" class="data row6 col3" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6dbed_row7_col0" class="data row7 col0" >Female</td>
#       <td id="T_6dbed_row7_col1" class="data row7 col1" >23</td>
#       <td id="T_6dbed_row7_col2" class="data row7 col2" >18</td>
#       <td id="T_6dbed_row7_col3" class="data row7 col3" >94</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6dbed_row8_col0" class="data row8 col0" >Male</td>
#       <td id="T_6dbed_row8_col1" class="data row8 col1" >64</td>
#       <td id="T_6dbed_row8_col2" class="data row8 col2" >19</td>
#       <td id="T_6dbed_row8_col3" class="data row8 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6dbed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6dbed_row9_col0" class="data row9 col0" >Female</td>
#       <td id="T_6dbed_row9_col1" class="data row9 col1" >30</td>
#       <td id="T_6dbed_row9_col2" class="data row9 col2" >19</td>
#       <td id="T_6dbed_row9_col3" class="data row9 col3" >72</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the cell above, I can verify that the exclusvive data columns which are 'CustomerID' have been removed as that Data Column is no longer there, leaving the rest of the Data Columns which will be used as Features.</p>

# %% [markdown]
# <hr/>
# <h2>2.4 Characteristics of Data</h2>

# %% [markdown]
# <p>In this sub-section, I will view the characteristics of my data such as the Numerical Characteristic for Numerical Data. I will also verify how large my dataset is and to verify the scale of the data that I am working with for Clustering.</p>

# %% [markdown]
# <hr/>
# <h3>2.4.1 Information of Data</h3>

# %% [markdown]
# <p>In the cell below, I will view the informaton of the dataset. The information will include the amount of data that is not missing and also the datatype for each of the Data Column. The operation will also display the total Data Rows for the dataframe.</p>

# %%
# ----------- Display Information Of DataFrame ----------- #
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               200 non-null    object
#  1   Age                  200 non-null    int64
#  2   Income (k$)          200 non-null    int64
#  3   How Much They Spend  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %% [markdown]
# <p>With reference to the output of the cell above, I am able to verify that there are no Missing Data as the RangeIndex has a total of 200 entries which matches up to the Non-Null Count which also has 200. However, this will need to be confirmed through a more conventional method later on. Through the output, I am also able to see that Gender is the only Categorical Data within the entire dataset which is supported by the previous observations in the previous subsections. Therefore, the Categorical Data need to be converted to a Numerical Data but with Scaling taken into account so as to not make Gender redundant during Clustering.</p>

# %% [markdown]
# <hr/>
# <h3>2.4.2 Shape of Data</h3>

# %% [markdown]
# <p>From the cell below, I will execute an operation which will display the amount of Data Rows and Data Columns that my dataset contains.</p>

# %%
# ----------- df's Shape ----------- #
shape_data = {'Attribute': ['Rows', 'Columns'], 'Count': list(df.shape)}

# ----------- Putting Shape Into DataFrame ----------- #
df_shape = pd.DataFrame(shape_data)

# ----------- Displaying DataFrame ----------- #
df_shape.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_fc470_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fc470_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fc470">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc470_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_fc470_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc470_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc470_row0_col0" class="data row0 col0" >Rows</td>
#       <td id="T_fc470_row0_col1" class="data row0 col1" >200</td>
#     </tr>
#     <tr>
#       <th id="T_fc470_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc470_row1_col0" class="data row1 col0" >Columns</td>
#       <td id="T_fc470_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the cell above, I am able to verify that the operation has been successfully executed. The data is represented in the format shown below. Thus, I can verify that there is a total of 200 Data Rows and 4 Data Columns, which is supported by the previous subsection.</p>
# \begin{equation}
# (Row , Column)
# \end{equation}

# %% [markdown]
# <hr/>
# <h3>2.4.3 Description of Data</h3>

# %% [markdown]
# <p>In the cell below, I will execute an operation which will describe the Numerical Data of the dataset The information displayed will include important information, especially mean (average) which can be used as a strategy to Impute Missing Data if there are any.</p>

# %%
# ----------- Describing DataFrame ----------- #
df.describe().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_bfaa2_row0_col0, #T_bfaa2_row0_col1, #T_bfaa2_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bfaa2_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_bfaa2_row1_col1, #T_bfaa2_row1_col2, #T_bfaa2_row5_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_bfaa2_row2_col0, #T_bfaa2_row3_col1, #T_bfaa2_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bfaa2_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_bfaa2_row2_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_bfaa2_row3_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_bfaa2_row4_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_bfaa2_row4_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_bfaa2_row4_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_bfaa2_row5_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_bfaa2_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_bfaa2_row6_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_bfaa2_row6_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_bfaa2_row6_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_bfaa2_row7_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_bfaa2_row7_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_bfaa2_row7_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bfaa2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfaa2_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_bfaa2_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_bfaa2_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfaa2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_bfaa2_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_bfaa2_row0_col1" class="data row0 col1" >200.000000</td>
#       <td id="T_bfaa2_row0_col2" class="data row0 col2" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_bfaa2_row1_col0" class="data row1 col0" >38.850000</td>
#       <td id="T_bfaa2_row1_col1" class="data row1 col1" >60.560000</td>
#       <td id="T_bfaa2_row1_col2" class="data row1 col2" >50.200000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_bfaa2_row2_col0" class="data row2 col0" >13.969007</td>
#       <td id="T_bfaa2_row2_col1" class="data row2 col1" >26.264721</td>
#       <td id="T_bfaa2_row2_col2" class="data row2 col2" >25.823522</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_bfaa2_row3_col0" class="data row3 col0" >18.000000</td>
#       <td id="T_bfaa2_row3_col1" class="data row3 col1" >15.000000</td>
#       <td id="T_bfaa2_row3_col2" class="data row3 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_bfaa2_row4_col0" class="data row4 col0" >28.750000</td>
#       <td id="T_bfaa2_row4_col1" class="data row4 col1" >41.500000</td>
#       <td id="T_bfaa2_row4_col2" class="data row4 col2" >34.750000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_bfaa2_row5_col0" class="data row5 col0" >36.000000</td>
#       <td id="T_bfaa2_row5_col1" class="data row5 col1" >61.500000</td>
#       <td id="T_bfaa2_row5_col2" class="data row5 col2" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_bfaa2_row6_col0" class="data row6 col0" >49.000000</td>
#       <td id="T_bfaa2_row6_col1" class="data row6 col1" >78.000000</td>
#       <td id="T_bfaa2_row6_col2" class="data row6 col2" >73.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfaa2_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_bfaa2_row7_col0" class="data row7 col0" >70.000000</td>
#       <td id="T_bfaa2_row7_col1" class="data row7 col1" >137.000000</td>
#       <td id="T_bfaa2_row7_col2" class="data row7 col2" >99.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the dataframe above, I am able to see the mean of all three Numerical Data and also see the wide range of Customer the business receives such as a large difference in the Age Demographic and Customers of varying Social-Economic Status and their Money Power.</p>

# %% [markdown]
# <hr/>
# <h1>3. Data Cleaning</h1>

# %% [markdown]
# <p>In this section, I will be conducting Data Cleaning. This process is extremely important as without this process, a model cannot be trained under any circumstances due to the data not being properly cleaned. Throughout this section, I will be checking, imputing and verifying missing datas for my datasets.</p>

# %% [markdown]
# <hr/>
# <h2>3.1 Checking For Missing Data</h2>

# %% [markdown]
# <p>In the cell below, I will be checking for the total amount of missing data value per category. By checking for the sum of the missing data, I can later compare it to the sum of missing data after I imputed the missing data.</p>

# %%
# ----------- Placing Missing Values Of df Into A Dataframe ----------- #
missingData = pd.DataFrame({'Missing Values': df.isnull().sum().values}, index = df.columns)

# ----------- Function For Colour Coding ----------- #
def colour_code(values):
    return 'background-color: green' if values == 0 else 'background-color: red'

# ----------- Calling Function For Colour Coding ----------- #
missingData = missingData.style.map(colour_code, subset = ['Missing Values'])

# ----------- Displaying Missing Values ----------- #
missingData
# Out:
# <style type="text/css">
# #T_95b75_row0_col0, #T_95b75_row1_col0, #T_95b75_row2_col0, #T_95b75_row3_col0 {
#   background-color: green;
# }
# </style>
# <table id="T_95b75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95b75_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95b75_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_95b75_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95b75_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_95b75_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95b75_level0_row2" class="row_heading level0 row2" >Income (k$)</th>
#       <td id="T_95b75_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_95b75_level0_row3" class="row_heading level0 row3" >How Much They Spend</th>
#       <td id="T_95b75_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output above, I am able to verify that there is no missing data within the dataset and that there is no need to impute any missing data for any of the Data Column. This allows me to subsequently proceed to check for Duplicated Data within the dataset.</p>

# %% [markdown]
# <hr/>
# <h2>3.2 Checking For Duplicated Data</h2>

# %% [markdown]
# <p>To address Duplicated Data, I have to verify if there are duplicated data in the first place. In the cell below, I will be checking for duplicated data and based on the output, one of the two action plan will occur.</p>
# <br/>
# <span style="color:red"><p><strong><u>Duplicated Data Identified</u></strong></p></span>
# <ul>
#     <li>Proceed to remove the duplicated data.</li>
# </ul>
# <span style="color:green"><p><strong><u>No Duplicated Data Identified</u></strong></p></span>
# <ul>
#     <li>Proceed with next sub-section on Fixing Data Types.</li>
# </ul>
# <br/>
# <p>With the action plan listed above, I will be proceeding to check for duplicated data.</p>

# %%
# ----------- Calculate Total Duplicated Rows ----------- #
duplicatesCount = df.duplicated().sum()

# ----------- Create DataFrame to Store Result ----------- #
duplicateSummary = pd.DataFrame({'Count': [duplicatesCount]}, index = ['Duplicated Rows'])

# ----------- Function for Colour Coding ----------- #
def colour_code(val):
    if val > 0:
        return 'background-color: red; color: white'
    else:
        return 'background-color: green; color: white'

# ----------- Apply Colour Coding to the 'Count' Column ----------- #
duplicateSummary = duplicateSummary.style.map(colour_code, subset=['Count'])

# ----------- Display the Result ----------- #
duplicateSummary
# Out:
# <style type="text/css">
# #T_f186f_row0_col0 {
#   background-color: green;
#   color: white;
# }
# </style>
# <table id="T_f186f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f186f_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f186f_level0_row0" class="row_heading level0 row0" >Duplicated Rows</th>
#       <td id="T_f186f_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the Dataframe above, I am able to verify that there are <span style="color:green"><strong><u>No Duplicated Data Identified</u></strong></span>. Therefore, I am able to proceed to Feature Engineering for the Dataset.</p>

# %% [markdown]
# <hr/>
# <h1>4. Feature Engineering</h1>

# %% [markdown]
# <p>In this section of Feature Engineering, I will be doing many operations such as creating dummy variables, removing outliers and creating new features. Feature Engineering plays an important role in ensuring my model can be trained with the dataset and also ensures that the accuracy of my model is not compromised in any case especially if it is due to the presence of outliers. However, many operation for Feature Engineering will be up to my discretion due to there not being a clear answer in many of the decisions which I need to make.</p>

# %% [markdown]
# <hr/>
# <h2>4.1 Dummy Variable for Gender</h2>

# %% [markdown]
# <p>I will be creating a Dummy Variable for the categorical data 'Gender'. This is because Clustering Models are not able to take in Categorical Data. Therefore, it will be much easier if I directly change the different Gender into Dummy Variable. I will also be using the 'One-Hot' method where instead of creating 2 columns, I will only be creating 1 columns to ensure the efficiency of training the models. The representation of the Dummy Variable is as follows,</p>
# <br/>
# <p><strong><u>Male</u></strong></p>
# <ul>
#     <li>Male = 1</li>
# </ul>
#
# <p><strong><u>Female</u></strong></p>
# <ul>
#     <li>Male = 0</li>
# </ul>
# <br/>
# <p>With the representation of the Dummy Variable listed out, I will proceed to execute the Dummy Variable Operation in the cell below.</p>

# %%
# ------------ Dummy Variable Creation Using One-Hot Method ------------ #
df = pd.get_dummies(df, columns = ['Gender'], prefix = 'Gender', drop_first = True, dtype = int)

# ------------ Displaying DataFrame ----------- #
df.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_30b5f_row0_col0, #T_30b5f_row0_col1, #T_30b5f_row1_col1, #T_30b5f_row2_col2, #T_30b5f_row2_col3, #T_30b5f_row3_col3, #T_30b5f_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_30b5f_row0_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_30b5f_row0_col3, #T_30b5f_row1_col2, #T_30b5f_row1_col3, #T_30b5f_row4_col0, #T_30b5f_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_30b5f_row1_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_30b5f_row2_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_30b5f_row2_col1, #T_30b5f_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_30b5f_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_30b5f_row3_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_30b5f_row4_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# </style>
# <table id="T_30b5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30b5f_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_30b5f_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_30b5f_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_30b5f_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30b5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30b5f_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_30b5f_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_30b5f_row0_col2" class="data row0 col2" >39</td>
#       <td id="T_30b5f_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30b5f_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_30b5f_row1_col1" class="data row1 col1" >15</td>
#       <td id="T_30b5f_row1_col2" class="data row1 col2" >81</td>
#       <td id="T_30b5f_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30b5f_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_30b5f_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_30b5f_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_30b5f_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30b5f_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_30b5f_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_30b5f_row3_col2" class="data row3 col2" >77</td>
#       <td id="T_30b5f_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30b5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_30b5f_row4_col0" class="data row4 col0" >31</td>
#       <td id="T_30b5f_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_30b5f_row4_col2" class="data row4 col2" >40</td>
#       <td id="T_30b5f_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the DataFrame output produced by the cell above, I can verify that the 'Gender' data column which was previously there has been removed and now there is 1 new Data Column called 'Gender_Male'. I am also able to verify that there are a mixture of combinattions which further support my inference that the 'Gender' data column have been successfully converted to a Dummy Variable. Therefore, with strong evidence supporting my assumption of the successful creation of Dummy Variable in place of 'Gender' data column, I will now move on to the next feature engineering that I will be executing.</p>

# %% [markdown]
# <hr/>
# <h2>4.2 Identifying Outliers</h2>

# %% [markdown]
# <p>In this sub-section, I will be Identifying Outliers using visualisations. Subsequently, I will need to address the Outliers accordingly on a case by case basis as some Outliers may not neccessarily have a negative effect. Outliers can cause a model to have lower accuracy level due to there being unrealistic datas which can skew the results, affecting the model's ability to cluster properly. The easiest and most used method to visualise outlier is using a Boxplot. A Boxplot will contain a few important parts such as the minimum, maximum, lower quartile, second quartile (median), and upper quartile. With all these parts present, I am able to perform and visualise important calculations such as the Inter-Quartile Range which will assist us in establishing the lower and upper fence should there be any Outliers. An Outlier will be flagged if it is below the Minimum or above the Maximum. Through the Boxplot, I am also able to visualise how many Outliers is present within a Numerical Category. As 'Gender' is represented by Dummy Variable, it will be excluded from this operation. The action plan for this section has been listed below.</p>
# <br/>
# <span style="color:red"><p><strong><u>Outliers Identified</u></strong></p></span>
# <ul>
#     <li>Proceed to determine the best course of action to undertake so as to address the Outlier.</li>
#     <li>Execute the planned out action in the next section.</li>
# </ul>
# <span style="color:green"><p><strong><u>No Outliers Identified</u></strong></p></span>
# <ul>
#     <li>Proceed to the next sub-section.</li>
# </ul>
# <br/>
# <p>With the action plan laid out, we will proceed to identify the Outliers in all Numerical Data.</p>

# %%
# ---------- Filter Numeric Columns Only ---------- #
numeric_columns = df.select_dtypes(include=['float64', 'int32', 'int64']).columns

# ---------- Plot Boxplots For All Numeric Columns ---------- #
plt.figure(figsize=(10, 11))
sns.boxplot(data=df[numeric_columns], orient='h', palette='coolwarm')
plt.title('Outliers Identification', fontsize=16)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.show()

# %% [markdown]
# <p>With reference to the output of the Boxplot above, I am able to determine that there is indeed an outlier for income where there is a data point at around 140k\$. Therefore, the result of the identification is concluded as <span style="color:red"><strong><u>Outliers Identified</u></strong></span>. The best course of action has been listed below.</p>
# <br/>
# <p><strong><u>Income (k\$)</u></strong></p>
# <ul>
#     <li>Course of Action: IQR Method</li>
#     <li>Reason: Due to Income (k\$) being skewed to the right.</li>
# </ul>
# <br/>
# <p>With the best Course of Action listed out, I will proceed to remove the Outlier from the Dataset.</p>

# %% [markdown]
# <hr/>
# <h2>4.3 Addressing Outliers Using IQR Method</h2>

# %% [markdown]
# <p>The IQR Method requires the establishment of a Upper Fence and Lower Fence such that any data which are above the Upper Fence will be deemed invalid and illegitimate and will be removed whereas any data which are below the Lower Fence will be deemed likewise and removed. In the cells below, I will be removing Outliers using the IQR Method.</p>
#
# $$\text{IQR} = \text{Q3} - \text{Q1}$$
# $$\text{Lower Fence} = \text{Q1} - 1.5 \times \text{IQR}$$
# $$\text{Upper Fence} = \text{Q3} + 1.5 \times \text{IQR}$$
# <br/>
# <p>With the formulas listed, I will proceed with identifying and removing the Outliers.</p>

# %%
# ---------- Columns With Outliers ---------- #
columns = [
    'Income (k$)'
]

# ---------- Function For Upper And Lower Bounds Calculations ---------- #
def calculate_bounds(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

# ---------- Flagging Of Outliers ---------- #
for col in columns:
    # Calculate bounds for the current column
    lower_bound, upper_bound = calculate_bounds(df[col])
    
    # Create a mask for outliers, ignoring NaN values
    df[f'Outlier_{col}'] = ((df[col] < lower_bound) | (df[col] > upper_bound)) & ~df[col].isna()

# ----------- Removal Of Outliers ---------- #
for col in columns:
    # Retain NaN values and remove only rows flagged as outliers
    df = df[(df[f'Outlier_{col}'] == False) | (df[col].isna())]

# ---------- Removal Of Data Column Used For Calculation ---------- #
outlier_cols = [f'Outlier_{col}' for col in columns]
df.drop(outlier_cols, axis=1, inplace=True)

# ---------- Filter Numeric Columns Only ---------- #
numeric_columns = df.select_dtypes(include=['float64', 'int32', 'int64']).columns

# ---------- Plot Boxplots for All Numeric Columns ---------- #
plt.figure(figsize=(10, 11))
sns.boxplot(data=df[numeric_columns], orient='h', palette='coolwarm')
plt.title('Outliers Identification', fontsize=16)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.show()

# %% [markdown]
# <p>With reference to the output of the Boxplot above, I am able to verify that the Outlier have been successfully removed and the Upper and Lower Fence have been successfully established. As there are no more Outliers remaining, I will proceed with Data Exploration of the new DataFrame.</p>

# %% [markdown]
# <hr/>
# <h2>4.4 Data Exploration of Updated DataFrame</h2>

# %% [markdown]
# <p>In this sub-section, I will be exploring the new DataFrame which have been ammended in the previous sub-section as the Outliers have been addressed. Thoughout this sub-section, I will mainly focus on what has changed compared to before the removal of some Outliers.</p>

# %% [markdown]
# <hr/>
# <h3>4.4.1 Shape of Updated DataFrame</h3>

# %% [markdown]
# <p>I will be running the shape method to view how many data rows are remaining as compared to before removing some of the Outliers. This will give me insights on what is the scale of the new data that I am working with.</p>

# %%
# ----------- df's Shape ----------- #
shape_data = {'Attribute': ['Rows', 'Columns'], 'Count': list(df.shape)}

# ----------- Putting Shape Into DataFrame ----------- #
df_shape = pd.DataFrame(shape_data)

# ----------- Displaying DataFrame ----------- #
df_shape.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_b3a78_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b3a78_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_b3a78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3a78_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_b3a78_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3a78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3a78_row0_col0" class="data row0 col0" >Rows</td>
#       <td id="T_b3a78_row0_col1" class="data row0 col1" >198</td>
#     </tr>
#     <tr>
#       <th id="T_b3a78_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3a78_row1_col0" class="data row1 col0" >Columns</td>
#       <td id="T_b3a78_row1_col1" class="data row1 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame, I am able to confirm that there was only a total of 2 Outliers which was removed using the IQR Method. This means that I did not lose much data as compared to the original 200 Data Rows.</p>

# %% [markdown]
# <hr/>
# <h3>4.4.2 Description of Updated DataFrame</h3>

# %% [markdown]
# <p>The last operation which I will perform on the new data is using the describe function. This will describe all the numerical data's information such as mean, standard deviation, etc. As all the data columns are now numerical, I should be able to see all the data column present.</p>

# %%
# ----------- Describing DataFrame ----------- #
df.describe().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_b88ee_row0_col0, #T_b88ee_row0_col1, #T_b88ee_row0_col2, #T_b88ee_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b88ee_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_b88ee_row1_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_b88ee_row1_col2, #T_b88ee_row5_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b88ee_row1_col3, #T_b88ee_row2_col0, #T_b88ee_row2_col3, #T_b88ee_row3_col1, #T_b88ee_row3_col2, #T_b88ee_row3_col3, #T_b88ee_row4_col3, #T_b88ee_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b88ee_row2_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b88ee_row2_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b88ee_row3_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b88ee_row4_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b88ee_row4_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b88ee_row4_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_b88ee_row5_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_b88ee_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b88ee_row6_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b88ee_row6_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b88ee_row6_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_b88ee_row6_col3, #T_b88ee_row7_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b88ee_row7_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b88ee_row7_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_b88ee_row7_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b88ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b88ee_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_b88ee_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_b88ee_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_b88ee_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b88ee_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b88ee_row0_col0" class="data row0 col0" >198.000000</td>
#       <td id="T_b88ee_row0_col1" class="data row0 col1" >198.000000</td>
#       <td id="T_b88ee_row0_col2" class="data row0 col2" >198.000000</td>
#       <td id="T_b88ee_row0_col3" class="data row0 col3" >198.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b88ee_row1_col0" class="data row1 col0" >38.929293</td>
#       <td id="T_b88ee_row1_col1" class="data row1 col1" >59.787879</td>
#       <td id="T_b88ee_row1_col2" class="data row1 col2" >50.196970</td>
#       <td id="T_b88ee_row1_col3" class="data row1 col3" >0.434343</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b88ee_row2_col0" class="data row2 col0" >14.016852</td>
#       <td id="T_b88ee_row2_col1" class="data row2 col1" >25.237259</td>
#       <td id="T_b88ee_row2_col2" class="data row2 col2" >25.746846</td>
#       <td id="T_b88ee_row2_col3" class="data row2 col3" >0.496927</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b88ee_row3_col0" class="data row3 col0" >18.000000</td>
#       <td id="T_b88ee_row3_col1" class="data row3 col1" >15.000000</td>
#       <td id="T_b88ee_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_b88ee_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b88ee_row4_col0" class="data row4 col0" >28.250000</td>
#       <td id="T_b88ee_row4_col1" class="data row4 col1" >40.500000</td>
#       <td id="T_b88ee_row4_col2" class="data row4 col2" >35.000000</td>
#       <td id="T_b88ee_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_b88ee_row5_col0" class="data row5 col0" >36.000000</td>
#       <td id="T_b88ee_row5_col1" class="data row5 col1" >61.000000</td>
#       <td id="T_b88ee_row5_col2" class="data row5 col2" >50.000000</td>
#       <td id="T_b88ee_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_b88ee_row6_col0" class="data row6 col0" >49.000000</td>
#       <td id="T_b88ee_row6_col1" class="data row6 col1" >77.750000</td>
#       <td id="T_b88ee_row6_col2" class="data row6 col2" >72.750000</td>
#       <td id="T_b88ee_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b88ee_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_b88ee_row7_col0" class="data row7 col0" >70.000000</td>
#       <td id="T_b88ee_row7_col1" class="data row7 col1" >126.000000</td>
#       <td id="T_b88ee_row7_col2" class="data row7 col2" >99.000000</td>
#       <td id="T_b88ee_row7_col3" class="data row7 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>From the DataFrame output by the cell above, I am able to verify that all the data columns are present. However, the numerical information should be ignored for 'Gender_Male'. This is because, despite them being Numerical Data, it is still a dummy variable. Therefore, the numerical information does not tell us any information about these data columns since the data is either '1' or '0'. However, we are able to see that the 'Income (k\$)' has a new max of 126 which indicated that the Outliers have caused some changes within the Data Column.</p>

# %% [markdown]
# <hr/>
# <h1>5. Data Visualisation</h1>

# %% [markdown]
# <p>In this section, I will be conducting various Data Visualisations using my data set. I will be doing Univariate Analysis and also Bivariate Analysis. I will also be looking out for trends and relationships between Features. Data Visualisation is extremely important within my project as it will allow me to visually interpret my data set and notice trends or patterns that numbers otherwise may not be able to show or display.</p>

# %% [markdown]
# <hr/>
# <h2>5.1 Univariate Analysis</h2>

# %% [markdown]
# <p>For this sub-section, I will be conducting Univariate Analysis on the features of my dataset. Through Univariate Analysis, I am able to verify the ratio, frequency and distributions of both Numerical and Categorical Features. This will allow me to identify patterns and give me insights on the data that I am utilising for clustering.</p>

# %% [markdown]
# <hr/>
# <h3>5.1.1 Analysis Using Histogram</h3>

# %% [markdown]
# <p>I will be utilising Histograms to visualise the distributions of my features. It will show me the frequency of the features in my dataset. I can also identify if the Histogram is positively-skewed, negatively-skewed, or normal. Within the Histogram, I am also able to identify the peak of each features that I have. For this visualisation, I will only be using Numerical Features and exclusing the Dummy Variables.</p>

# %%
# ------------ Define Features For Plotting ----------- #
features = ['Age', 'Income (k$)', 'How Much They Spend']

# ------------ Seaborn Style ---------- #
sns.set_style("whitegrid")

# ------------ Plotting Histogram ----------- #
for feature in features:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[feature], bins=20, kde=True, color="royalblue", alpha=0.7, edgecolor="black")
    
    # Titles And Labels #
    plt.title(f'Distribution of {feature}', fontsize=14, fontweight='bold')
    plt.xlabel(feature, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    
    # Enhancing Grid And Aesthetics #
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    
    # Display Plot # 
    plt.show()

# %% [markdown]
# <p>With reference to the Histogram aboe, I am able to see that generally the Age of customers are in their 30s, the Income is normally around 60k$ and the spending is around 50.</p>

# %% [markdown]
# <hr/>
# <h3>5.1.2 Analysis Using Pie Chart For Gender</h3>

# %% [markdown]
# <p>By utilising a Pie Chart, I am able to see the ratio of Male to Female within our Dataset. This will indicate whether the customers are mainly Female or Male so as to find a specific Gender to target. This information cann be used for targetted marketing and also help the Shop to prioritise certain customers.</p>

# %%
# ----------- Defining Figure Size ---------- #
plt.figure(figsize=(6, 6))

# ---------- Labelling Dummy Variable ---------- #
gender_counts = df['Gender_Male'].value_counts()
gender_labels = ['Female', 'Male']

# ----------- Defining Colours And Explode ----------- #
colors = ['lightcoral', 'royalblue']
explode = (0.05, 0)

# ----------- Plotting Of Pie Chart ----------- #
sns.set_style("whitegrid")
plt.pie(gender_counts, labels=gender_labels, autopct='%1.1f%%', 
        colors=colors, explode=explode, startangle=140, shadow=True, 
        wedgeprops={'edgecolor': 'black'})

# ------------ Title And Styling ----------- #
plt.title("Gender Distribution", fontsize=14, fontweight='bold')

# ------------ Displaying Plot ------------ #
plt.show()

# %% [markdown]
# <p>With reference to the Pie Chart above, I am able to see that there are more female customers than male customers.</p>

# %% [markdown]
# <hr/>
# <h2>5.2 Bivariate Analysis</h2>

# %% [markdown]
# <p>In this sub-section, I will be conducting Bivariate Analysis on my Features. The analysis will not be solely isolated to numerical features but also to categorical features (which are now dummy variables). Through Bivariate Analysis, I hope to gather insights on the datas and also see the relationship between features. This will help me better understand the general relationship between features and also why certain values within a feature are higher than others.</p>

# %% [markdown]
# <hr/>
# <h3>5.2.1 Heatmap For Correlation</h3>

# %% [markdown]
# <p>To ensure there are no high correlation between features, I will be utilising a Heatmap to see the Correlation Value. Should there be any features with a high correlation value, I will be dropping one of the features.</p>

# %%
# ----------- Defining Figure Size ---------- #
plt.figure(figsize=(15, 10))

# ----------- Plotting Of Heatmap ----------- #
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", linewidths=0.5)

# ---------- Title ---------- #
plt.title("Feature Correlation Heatmap")

# ----------- Displaying Heatmap ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Heatmap above, I am able to confirm that there are no Features with high correlation. Therefore, there is no need to drop any features in particular and the Clustering will not be affected due to issues concerning the Correlation.</p>

# %% [markdown]
# <hr/>
# <h3>5.2.2 Pairplot Correlation Analysis</h3>

# %% [markdown]
# <p>I will be utilising a Pairplot to identify for potential correlation between Features that will be used for Clustering. Should there be any feautres which have a high correlation, I will be removing one of the features so as to not affect the clustering.</p>

# %%
# ----------- Plotting Of Pairplot ----------- #
sns.pairplot(df, hue="Gender_Male")

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Pairplot, I am able to see that there is no features with high correlation. Therefore, no features need to be removed and the Clustering Quality will not be affected.</p>

# %% [markdown]
# <hr/>
# <h3>5.3.3 Comparison of Spending By Gender</h3>

# %% [markdown]
# <p>To determine whether there is a major difference in certain features between Genders, I will be using a boxplot and use the median as a determining factor on the feature</p>

# %%
# ----------- Defining Figure Size ---------- #
plt.figure(figsize=(8, 5))

# ----------- Plotting Of Boxplot ----------- #
sns.boxplot(x=df['Gender_Male'], y=df['How Much They Spend'], palette=["lightcoral", "royalblue"])

# ----------- Titles And Lables ----------- #
plt.xticks([0, 1], ["Female", "Male"])
plt.title("Spending by Gender", fontsize=14, fontweight='bold')
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Spending", fontsize=12)
plt.grid(alpha=0.5, linestyle='--')

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Boxplot above, I am able to see that generally, there are no difference between the spending between Male and Female. Therefore, I will not be using Male and Female in the clustering as this may only yield results for more clusters which separates the Genders.</p>

# %% [markdown]
# <hr/>
# <h3>5.3.4 Comparison of Income By Gender</h3>

# %% [markdown]
# <p>To determine whether there is a major difference in certain features between Genders, I will be using a boxplot and use the median as a determining factor on the feature</p>

# %%
# ----------- Defining Figure Size ---------- #
plt.figure(figsize=(8, 5))

# ----------- Plotting Of Boxplot ----------- #
sns.boxplot(x=df['Gender_Male'], y=df['Income (k$)'], palette=["lightcoral", "royalblue"])

# ----------- Titles And Lables ----------- #
plt.xticks([0, 1], ["Female", "Male"])
plt.title("Income by Gender", fontsize=14, fontweight='bold')
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Income (k$)", fontsize=12)
plt.grid(alpha=0.5, linestyle='--')

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Boxplot above, I am able to see that generally, there are no difference between the Income between Male and Female. Therefore, I will not be using Male and Female in the clustering as this may only yield results for more clusters which separates the Genders.</p>

# %% [markdown]
# <hr/>
# <h1>5. Scaling of Features</h1>

# %% [markdown]
# <p>As most clustering models requires Normalisation as different features have different unit of measurements and ranges, I will be scaling my Features to ensure large numerical values do not dominate the clustering and leave the numerical values of lower counts redundant. There is 2 main methods for Scaling Features for which I will be utilising. These two methods are listed below in the sub-sections.</p>

# %% [markdown]
# <hr/>
# <h2>5.1 Z-Score Standardisation</h2>

# %% [markdown]
# <p>Z-Score Standardisation will scale down the data such that the mean will be 0 while the Standard Deviation is 1 by calculating the Z-Score of the dataset. The formula is listed below as reference to how this works.</p>
#
# $$
# X' = \frac{X - \mu}{\sigma}
# $$
#
# **Where:**
# - $X'$ is the standardised feature value
# - $X$ is the original feature value
# - $\mu$ is the mean of the feature
# - $\sigma$ is the standard deviation of the feature
#
# <br/>
# <p>With reference to the purpose and capability of the Z-Score Standardisation, I will proceed to scale the data using the Z-Score Standardisation in the cell below.</p>

# %%
# ----------- Selecting Numerical Features For Scaling ----------- #
features_to_scale = ['Age', 'Income (k$)', 'How Much They Spend']

# ------------ Applying Z-Score Standardisation ----------- #
scaler_zscore = StandardScaler()
df_zscore = df.copy()
df_zscore[features_to_scale] = scaler_zscore.fit_transform(df[features_to_scale])

# ------------ Displaying Z-Score Standardisation DataFrame ----------- #
df_zscore.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_77efb_row0_col0, #T_77efb_row0_col1, #T_77efb_row1_col1, #T_77efb_row2_col2, #T_77efb_row2_col3, #T_77efb_row3_col3, #T_77efb_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_77efb_row0_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_77efb_row0_col3, #T_77efb_row1_col2, #T_77efb_row1_col3, #T_77efb_row4_col0, #T_77efb_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_77efb_row1_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_77efb_row2_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_77efb_row2_col1, #T_77efb_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_77efb_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_77efb_row3_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_77efb_row4_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# </style>
# <table id="T_77efb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77efb_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_77efb_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_77efb_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_77efb_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77efb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77efb_row0_col0" class="data row0 col0" >-1.425414</td>
#       <td id="T_77efb_row0_col1" class="data row0 col1" >-1.779171</td>
#       <td id="T_77efb_row0_col2" class="data row0 col2" >-0.435989</td>
#       <td id="T_77efb_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_77efb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77efb_row1_col0" class="data row1 col0" >-1.282367</td>
#       <td id="T_77efb_row1_col1" class="data row1 col1" >-1.779171</td>
#       <td id="T_77efb_row1_col2" class="data row1 col2" >1.199413</td>
#       <td id="T_77efb_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_77efb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77efb_row2_col0" class="data row2 col0" >-1.353890</td>
#       <td id="T_77efb_row2_col1" class="data row2 col1" >-1.739447</td>
#       <td id="T_77efb_row2_col2" class="data row2 col2" >-1.720949</td>
#       <td id="T_77efb_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_77efb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77efb_row3_col0" class="data row3 col0" >-1.139319</td>
#       <td id="T_77efb_row3_col1" class="data row3 col1" >-1.739447</td>
#       <td id="T_77efb_row3_col2" class="data row3 col2" >1.043661</td>
#       <td id="T_77efb_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_77efb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77efb_row4_col0" class="data row4 col0" >-0.567131</td>
#       <td id="T_77efb_row4_col1" class="data row4 col1" >-1.699723</td>
#       <td id="T_77efb_row4_col2" class="data row4 col2" >-0.397051</td>
#       <td id="T_77efb_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to confirm that the Z-Score Standardisation have been executed successfully as the Data are now scaled accordingly for all Numerical Data Column.</p>

# %% [markdown]
# <hr/>
# <h2>5.2 Min-Max Scaler</h2>

# %% [markdown]
# <p>Min-Max Scaler will scale the data down such that it ranges between 0 and 1.</p>
#
# $$
# X' = \frac{X - X_{\min}}{X_{\max} - X_{\min}}
# $$
#
# **Where:**
# - $X'$ is the scaled feature value
# - $X$ is the original feature value
# - $X_{\min}$ is the minimum value of the feature
# - $X_{\max}$ is the maximum value of the feature
#
# <p>With the function fo the Min-Max Scaler indicated, I will proceed to utilise the Min-Max Scaler to scale my data in the cell below.</p>

# %%
# ----------- Selecting Numerical Features For Scaling ----------- #
features_to_scale = ['Age', 'Income (k$)', 'How Much They Spend']

# ------------ Applying Min-Max Scaling ----------- #
scaler_minmax = MinMaxScaler()
df_minmax = df.copy()
df_minmax[features_to_scale] = scaler_minmax.fit_transform(df[features_to_scale])

# ------------ Displaying Z-Score Standardisation DataFrame ----------- #
df_minmax.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_41247_row0_col0, #T_41247_row0_col1, #T_41247_row1_col1, #T_41247_row2_col2, #T_41247_row2_col3, #T_41247_row3_col3, #T_41247_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_41247_row0_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_41247_row0_col3, #T_41247_row1_col2, #T_41247_row1_col3, #T_41247_row4_col0, #T_41247_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_41247_row1_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_41247_row2_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_41247_row2_col1, #T_41247_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_41247_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_41247_row3_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_41247_row4_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# </style>
# <table id="T_41247">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41247_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_41247_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_41247_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_41247_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41247_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41247_row0_col0" class="data row0 col0" >0.019231</td>
#       <td id="T_41247_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_41247_row0_col2" class="data row0 col2" >0.387755</td>
#       <td id="T_41247_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_41247_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41247_row1_col0" class="data row1 col0" >0.057692</td>
#       <td id="T_41247_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_41247_row1_col2" class="data row1 col2" >0.816327</td>
#       <td id="T_41247_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_41247_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41247_row2_col0" class="data row2 col0" >0.038462</td>
#       <td id="T_41247_row2_col1" class="data row2 col1" >0.009009</td>
#       <td id="T_41247_row2_col2" class="data row2 col2" >0.051020</td>
#       <td id="T_41247_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_41247_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41247_row3_col0" class="data row3 col0" >0.096154</td>
#       <td id="T_41247_row3_col1" class="data row3 col1" >0.009009</td>
#       <td id="T_41247_row3_col2" class="data row3 col2" >0.775510</td>
#       <td id="T_41247_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_41247_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41247_row4_col0" class="data row4 col0" >0.250000</td>
#       <td id="T_41247_row4_col1" class="data row4 col1" >0.018018</td>
#       <td id="T_41247_row4_col2" class="data row4 col2" >0.397959</td>
#       <td id="T_41247_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to confirm that the Min-Max Scaler have been executed successfully as the Data are now scaled accordingly for all Numerical Data Column.</p>

# %% [markdown]
# <hr/>
# <h2>5.3 Visualising Scaled Data</h2>

# %% [markdown]
# <p>In order to verify that the integrity of the Data is still the same as the Original Data despite the scaling, I will be plotting 3 sets of Histograms that represents the Original Data, Z-Score Standardised Data and Min-Max Scaled Data. I will them compare the kde for each of the plots in the same Data Column so as to ensure that the kde is generally similar but the value isn't due to scaling. The Histogram will be plot in the cell below.</p>

# %%
# ----------- Seaborn Styling ----------- #
sns.set_style("whitegrid")

# ------------ Plotting Of Histogram ----------- #
def compare_scaling(feature):
    plt.figure(figsize=(12, 5))

    # Original Data #
    plt.subplot(1, 3, 1)
    sns.histplot(df[feature], bins=20, kde=True, color="blue", alpha=0.2, edgecolor="black")
    plt.title(f'Original {feature}', fontsize=12)
    plt.xlabel(feature)

    # Z-Score Standardisation #
    plt.subplot(1, 3, 2)
    sns.histplot(df_zscore[feature], bins=20, kde=True, color="green", alpha=0.2, edgecolor="black")
    plt.title(f'Z-Score Standardised {feature}', fontsize=12)
    plt.xlabel(feature)

    # Min-Max Scaling #
    plt.subplot(1, 3, 3)
    sns.histplot(df_minmax[feature], bins=20, kde=True, color="red", alpha=0.2, edgecolor="black")
    plt.title(f'Min-Max Scaled {feature}', fontsize=12)
    plt.xlabel(feature)

    # Displaying Plot #
    plt.tight_layout()
    plt.show()

# ------------ Plotting For All Features ----------- #
for feature in features_to_scale:
    compare_scaling(feature)

# %% [markdown]
# <p>With reference to the output of the Histograms with the KDEs, I am able to verify that the Scaling did not affect the integrity or the distribution of the data, instead, the only thing that has been affected is the Numerical Data which was all scalled to a lower amount so as to ensure Normalisation amongst all the Numerical Data in the Dataset.</p>

# %% [markdown]
# <hr/>
# <h1>6. Clustering</h1>

# %% [markdown]
# <p>I will be proceeding to conduct the clustering for my Dataset. In this section, I will primarily be using 3 different methods of clustering and subsequently cross referring the results to each other. Afterwards, I will fine tune each of the Clustering Models to determine the most ideal and suitable model to utlise for my dataset. The models that I will be utilising are indicated below.</p>
# <br/>
# <p><strong><u>K-Means (Centroid Based)</u></strong></p>
# <ul>
#     <li>Purpose: Partitions Data into k clusters, aiming to minimise intra-cluster variance (WCSS - Within-Cluster Sum of Squares) and best for well-separated data.</li>
# </ul>
# <p><strong><u>Agglomerative Clustering (Hierarchical Clustering)</u></strong></p>
# <ul>
#     <li>Purpose: Recursively merges data points into a Hierarchical Tree (Dendrogram). It does not require k beforehand and is best suited for nested or hierarchical structures.</li>
# </ul>
# <p><strong><u>DBSCAN (Density-Based Spatial Clustering of Applications with Noise)</u></strong></p>
# <ul>
#     <li>Purpose: Groups data points based on density and does not require specifying k and is ideal for detecting arbitrary-shaped clusters.</li>
# </ul>
# <br/>
# <p>With the models listed, I will proceed to utilise each of the model in the cells below.</p>

# %% [markdown]
# <hr/>
# <h2>6.1 K-Means (Centroid Based)</h2>

# %% [markdown]
# <p>K-Means is a centroid-based clustering algorithm that partitions data into k clusters, aiming to minimise intra-cluster variance (WCSS - Within-Cluster Sum of Squares). It is best for well-separated, spherical clusters. I have listed the strengths and weaknesses of K-Means below.</p>
# <br/>
# <span style="color:green"><p><strong><u>Strengths</u></strong></p></span>
# <ul>
#     <li>Fast & Scalable</li>
#     <li>Easy Implementation & Interpretation</li>
#     <li>Works Well With Spherical Clusters</li>
#     <li>Able To Handle High Dimension Data</li>
# </ul>
# <span style="color:red"><p><strong><u>Weaknesses</u></strong></p></span>
# <ul>
#     <li>k Needs To Be Predefined</li>
#     <li>Sensitive To Outliers</li>
#     <li>Struggles With Non-Speherical Clusters</li>
#     <li>Sensitive To Initialisation</li>
# </ul>
# <br/>
# <p>With the context of the Strengths and Weaknesses of K-Means in mind, I will proceed to find the optimal k-cluster in the next sub-section.</p>

# %% [markdown]
# <hr/>
# <h3>6.1.1 Deciding Best Scaling For K-Means</h3>

# %% [markdown]
# <p>I conducted 2 methods of Scaling previously which are the Z-Score Standardisation and the Min-Max Scaling. These 2 methods utilised different methods of adjusting the Numerical Value which was stated previosuly. I will be comparing the WCSS and Silhouette Score of the Min-Max Scaling Data and the Z-Score Standardisation Data. The formula for WCSS and Silhouette Score have been indicated below.</p>
#
# $$
# WCSS = \sum_{i=1}^{k} \sum_{x \in C_i} ||x - \mu_i||^2
# $$
#
# **Where:**
# - $k$ → Number of clusters
# - $C_i$ → Cluster $i$
# - $x$ → Data point in cluster $C_i$
# - $\mu_i$ → Centroid of cluster $C_i$
# - $||x - \mu_i||^2$ → Squared Euclidean distance between each data point and its cluster centroid
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Where:**
# - $S(i)$ → Silhouette Score of point $i$
# - $a(i)$ → Average distance between point $i$ and other points in the same cluster
# - $b(i)$ → Average distance between point $i$ and the nearest neighboring cluster
# - $-1 \leq S(i) \leq 1$, where:
#   - $S(i)$ close to **1** → Well clustered
#   - $S(i)$ close to **0** → Overlapping clusters
#   - $S(i)$ close to **-1** → Incorrect clustering
#
# <br/>
# <p>With the formula listed, I will proceed to plot out the Graphs to identify the Best Scaling Method to use for K-Means.</p>

# %%
# ---------- Defining Range Of K-Clusters ----------- #
k_values = range(2, 11)

# ---------- Initiate List To Store Results ----------- #
wcss_minmax, silhouette_scores_minmax = [], []
wcss_zscore, silhouette_scores_zscore = [], []

# ----------- Computing Cluster Metrics ----------- #
for k in k_values:
    # K-Means On Min-Max Scaled Data #
    kmeans_minmax = KMeans(n_clusters=k, random_state=42, n_init=10)
    cluster_labels_minmax = kmeans_minmax.fit_predict(df_minmax[features_to_scale])
    wcss_minmax.append(kmeans_minmax.inertia_)
    silhouette_scores_minmax.append(silhouette_score(df_minmax[features_to_scale], cluster_labels_minmax))

    # K-Means On Z-Score Standardized Data #
    kmeans_zscore = KMeans(n_clusters=k, random_state=42, n_init=10)
    cluster_labels_zscore = kmeans_zscore.fit_predict(df_zscore[features_to_scale])
    wcss_zscore.append(kmeans_zscore.inertia_)
    silhouette_scores_zscore.append(silhouette_score(df_zscore[features_to_scale], cluster_labels_zscore))

# ----------- Defining Subplots ----------- #
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ------------ Elbow Method For WCSS Comparison ----------- #
axes[0].plot(k_values, wcss_minmax, marker='o', linestyle='--', color='b', label="Min-Max Scaling")
axes[0].plot(k_values, wcss_zscore, marker='o', linestyle='--', color='r', label="Z-Score Standardization")
axes[0].set_xlabel('Number of Clusters (k)', fontsize=12)
axes[0].set_ylabel('WCSS (Within-Cluster Sum of Squares)', fontsize=12)
axes[0].set_title('Elbow Method for Min-Max vs Z-Score Scaling', fontsize=14, fontweight='bold')
axes[0].legend()
axes[0].grid(True, which="both", linestyle="--", alpha=0.7)

# ----------- Silhouette Scores Comparison ----------- #
axes[1].plot(k_values, silhouette_scores_minmax, marker='o', linestyle='--', color='b', label="Min-Max Scaling")
axes[1].plot(k_values, silhouette_scores_zscore, marker='o', linestyle='--', color='r', label="Z-Score Standardization")
axes[1].set_xlabel('Number of Clusters (k)', fontsize=12)
axes[1].set_ylabel('Silhouette Score', fontsize=12)
axes[1].set_title('Silhouette Score for Min-Max vs Z-Score Scaling', fontsize=14, fontweight='bold')
axes[1].legend()
axes[1].grid(True)

# ------------ Displaying Plot ----------- #
plt.tight_layout()
plt.show()

# %% [markdown]
# <p>With reference to the output to the Line Plot for the WCSS and the Silhouette Score, I am able to see that Min-Max Scaling has a lower WCSS while Z-Score Standardisation has a higher WCSS. For the Silhouette Score, I am able to see that the Min-Max has a lower Silhouette Score compared to Z-Score Standardisation. The observations and conclusion are listed below.</p>
# <br/>
# <p><strong><u>Min-Max Scaling</u></strong></p>
# <ul>
#     <li>Within Cluster Sum of Squares: Min-Max Scaling has a very low WCSS at around 25.</li>
#     <li>Silhouette Score: Min-Max Scaling has a moderate Silhouette Score, peaking at 0.42 for 6 Clusters.</li>
# </ul>
# <p><strong><u>Z-Score Standardisation</u></strong></p>
# <ul>
#     <li>Within Cluster Sum of Squares: Z-Score Standardisation has a relatively higher WCSS between 400 and 90.</li>
#     <li>Silhouette Score: Z-Score Standardisation has a higher Silhouette Score, peaking at 0.43 for 6 Clusters.</li>
# </ul>
# <p><strong><u>Conclusion</u></strong></p>
# <ul>
#     <li>Scaling Method To Use: Z-Score Standardisation.</li>
#     <li>Reason: Performed better in Silhouette Score than Min-Max Scaling.</li>
# </ul>
# <p>With the observation and conclusion listed out, I will proceed to find the Optimal K-Clusters and Compare the PCA results with the Original Data.</p>

# %% [markdown]
# <hr/>
# <h3>6.1.2 Finding Optimal K-Clusters And Reducing Dimensions</h3>

# %% [markdown]
# <p>As K-Means required a k-cluser to be predefined, I will be utilising the Elbow Method and Sillhouette Score to find the Optimal k. The reason for utilising 2 methods is such that should one of the method fail, there will be another method to fallback on. It will also provide a cross reference so as to confirm the Optimal K-Clusters based on different metrics. The computation for the WCSS and Sillhouette Score are indcated below. I will also be using Principal Component Analysis to reduce the dimensions of the Data to compare the results and determine if it improves the Silhouette Score. The formula for PCA is also indicated below.</p>
# <br/>
#
# $$
# WCSS = \sum_{i=1}^{k} \sum_{x \in C_i} ||x - \mu_i||^2
# $$
#
# **Where:**
# - $k$ → Number of clusters
# - $C_i$ → Cluster $i$
# - $x$ → Data point in cluster $C_i$
# - $\mu_i$ → Centroid of cluster $C_i$
# - $||x - \mu_i||^2$ → Squared Euclidean distance between each data point and its cluster centroid
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Where:**
# - $S(i)$ → Silhouette Score of point $i$
# - $a(i)$ → Average distance between point $i$ and other points in the same cluster
# - $b(i)$ → Average distance between point $i$ and the nearest neighboring cluster
# - $-1 \leq S(i) \leq 1$, where:
#   - $S(i)$ close to **1** → Well clustered
#   - $S(i)$ close to **0** → Overlapping clusters
#   - $S(i)$ close to **-1** → Incorrect clustering
#
# $$
# Z = X W
# $$
#
# **Where:**
# - $ Z $ is the transformed data in the new principal component space.
# - $ X $ is the original data matrix (centered by subtracting the mean).
# - $ W $ is the matrix of eigenvectors (principal components).
#
# $$
# C = \frac{1}{n} X^T X
# $$
#
# **Where:**
# - $ C $ is the covariance matrix of $ X $.
# - $ n $ is the number of samples.
#
# $$
# C W = \lambda W
# $$
#
# **Where:**
#
# - $ \lambda $ are the eigenvalues.
# - $ W $ are the corresponding eigenvectors (principal components).
# <br/>
# <p>With the formulas listed, I will proceed to plot the Line Graph and conduct PCA in the cell below so as to identify the optimal K-Cluster.</p>

# %%
# ---------- Defining Range Of K-Clusters ----------- #
k_values = range(2, 11)

# ----------- Applying PCA ----------- #
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_zscore[features_to_scale])

# ---------- Initiate List To Store Results ----------- #
wcss_original, silhouette_scores_original = [], []
wcss_pca, silhouette_scores_pca = [], []

# ----------- Computing Cluster Metrics ----------- #
for k in k_values:
    # K-Means On Original Data #
    kmeans_original = KMeans(n_clusters=k, random_state=42, n_init=10)
    cluster_labels_original = kmeans_original.fit_predict(df_zscore[features_to_scale])
    wcss_original.append(kmeans_original.inertia_)
    silhouette_scores_original.append(silhouette_score(df_zscore[features_to_scale], cluster_labels_original))

    # K-Means On PCA Data #
    kmeans_pca = KMeans(n_clusters=k, random_state=42, n_init=10)
    cluster_labels_pca = kmeans_pca.fit_predict(pca_result)
    wcss_pca.append(kmeans_pca.inertia_)
    silhouette_scores_pca.append(silhouette_score(pca_result, cluster_labels_pca))

# ----------- Defining Subplots ----------- #
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# ------------ Elbow Method For WCSS Comparison ----------- #
axes[0, 0].plot(k_values, wcss_original, marker='o', linestyle='--', color='blue', label="Original")
axes[0, 0].plot(k_values, wcss_pca, marker='o', linestyle='--', color='green', label="PCA")
axes[0, 0].set_xlabel('Number of Clusters (k)', fontsize=12)
axes[0, 0].set_ylabel('WCSS', fontsize=12)
axes[0, 0].set_title('Elbow Method for Original, PCA, and t-SNE', fontsize=14, fontweight='bold')
axes[0, 0].legend()
axes[0, 0].grid(True)

# ----------- Silhouette Scores Comparison ----------- #
axes[0, 1].plot(k_values, silhouette_scores_original, marker='o', linestyle='--', color='blue', label="Original")
axes[0, 1].plot(k_values, silhouette_scores_pca, marker='o', linestyle='--', color='green', label="PCA")
axes[0, 1].set_xlabel('Number of Clusters (k)', fontsize=12)
axes[0, 1].set_ylabel('Silhouette Score', fontsize=12)
axes[0, 1].set_title('Silhouette Score for Original and PCA', fontsize=14, fontweight='bold')
axes[0, 1].legend()
axes[0, 1].grid(True)

# ------------ WCSS Bar Plot For Best k ----------- #
best_k = 6
axes[1, 0].bar(['Original', 'PCA'], [wcss_original[best_k-2], wcss_pca[best_k-2]], color=['blue', 'green'])
axes[1, 0].set_xlabel('Dimensionality Reduction Method', fontsize=12)
axes[1, 0].set_ylabel('WCSS (Within-Cluster Sum of Squares)', fontsize=12)
axes[1, 0].set_title(f'WCSS for k={best_k}', fontsize=14, fontweight='bold')
axes[1, 0].grid(axis='y', linestyle='--', alpha=0.7)

# ------------ Silhouette Scores Bar Plot For Best k ----------- #
axes[1, 1].bar(['Original', 'PCA'], [silhouette_scores_original[best_k-2], silhouette_scores_pca[best_k-2]], color=['blue', 'green'])
axes[1, 1].set_xlabel('Dimensionality Reduction Method', fontsize=12)
axes[1, 1].set_ylabel('Silhouette Score', fontsize=12)
axes[1, 1].set_title(f'Silhouette Score for k={best_k}', fontsize=14, fontweight='bold')
axes[1, 1].grid(axis='y', linestyle='--', alpha=0.7)

# ------------- Displaying Plot ------------- #
plt.tight_layout()
plt.show()

# %% [markdown]
# <p>With reference to the output of the Line Graph showing the Elbow Method and Silhouette Score for the Optimal k, I am able to come to the conclusion that the Optimal K is 6. The observation for each of the method respectively have been indicated below.</p>
# <br/>
# <p><strong><u>Elbow Method</u></strong></p>
# <ul>
#     <li>At k = 6, the rate of WCSS decrease slows down.</li>
# </ul>
# <p><strong><u>Sihouette Method</u></strong></p>
# <ul>
#     <li>At k = 6, the Silhoutte Score peaked the highest at around 0.46.</li>
# </ul>
# <p><strong><u>Dimension Reduction</u></strong></p>
# <ul>
#     <li>Use Orginal Data due to higher Silhouette Score.</li>
# </ul>
# <br/>
# <p>Therefore, with the observations laid out and the ideal cluster of 6 determined, I will proceed to clustering using K-Means.</p>

# %% [markdown]
# <hr/>
# <h3>6.1.3 Visualising Clusters Using t-SNE</h3>

# %% [markdown]
# <p>After finding the Optimal k-Cluster, I will proceed to visualise the Clusters by reducing the Dimensions using t-SNE and subsequently using a Scatterplot to viusalise the 6 Clusters. t-SNE allows us to reduce the dimensions into 2 dimensions to allow for a better visualisation. The formula for t-SNE is indicated below.</p>
#
# The probability distribution in high-dimensional space is defined as:
#
# $$ P_{j|i} = \frac{\exp(-||x_i - x_j||^2 / 2\sigma_i^2)}{\sum_{k \neq i} \exp(-||x_i - x_k||^2 / 2\sigma_i^2)} $$
#
# Where:
#
# - $ P_{j|i} $ is the conditional probability that point $ x_j $ is chosen as a neighbor of point $ x_i $.
# - $ x_i, x_j $ are high-dimensional data points.
# - $ \sigma_i $ is the bandwidth of the Gaussian kernel for point $ x_i $.
#
# The probability distribution in low-dimensional space is:
#
# $$ Q_{j|i} = \frac{(1 + ||y_i - y_j||^2)^{-1}}{\sum_{k \neq i} (1 + ||y_i - y_k||^2)^{-1}} $$
#
# Where:
#
# - $ Q_{j|i} $ is the conditional probability in the lower-dimensional space.
# - $ y_i, y_j $ are the mapped points in the lower-dimensional space.
#
# The Kullback-Leibler (KL) divergence, which t-SNE minimizes, is given by:
#
# $$ KL(P||Q) = \sum_i \sum_j P_{ij} \log \frac{P_{ij}}{Q_{ij}} $$
#
# Where:
#
# - $ KL(P||Q) $ measures the difference between the high-dimensional and low-dimensional distributions.
# - $ P_{ij} $ and $ Q_{ij}
# - $ are the symmetric joint probabilities.
#
# <br/>
# <p>With the formula indicated, I will proceed to conduct the visualisation in the cell below.</p>

# %%
# ----------- Defining Optimal K-Clusters ------------ #
optimal_k = 6

# ------------- Applying K-Means On Scaled Data ------------ #
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df_zscore['Cluster'] = kmeans.fit_predict(df_zscore[features_to_scale])

# ----------- Extracting Cluster Centers ------------ #
cluster_centers = kmeans.cluster_centers_

# -------------- Applying t-SNE For Visualisation ------------- #
tsne = TSNE(n_components=2, random_state=42, perplexity=30, learning_rate=200)
tsne_results = tsne.fit_transform(df_zscore[features_to_scale])

# ------------ Adding t-SNE Results Into DataFrame ------------ #
df_zscore['TSNE1'] = tsne_results[:, 0]
df_zscore['TSNE2'] = tsne_results[:, 1]

# ------------ Visualising t-SNE Clusters ------------ #
plt.figure(figsize=(15, 9))
sns.scatterplot(x=df_zscore['TSNE1'], y=df_zscore['TSNE2'], hue=df_zscore['Cluster'], 
                palette='Set1', alpha=0.7, edgecolor='black')

# ------------- Titles And Labels ------------ #
plt.xlabel('t-SNE Component 1', fontsize=12)
plt.ylabel('t-SNE Component 2', fontsize=12)
plt.title('Visualization of Clusters using t-SNE', fontsize=14, fontweight='bold')
plt.legend(title="Cluster")
plt.grid(True)

# ------------ Displaying Plot ------------ #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Visualisation of Clusters above, I am able to observe that the clusters are generally well-clustered with a few exceptions. I will proceed to test out the other method of clustering and conduct cross referencing on the quality of clustering.</p>

# %% [markdown]
# <hr/>
# <h3>6.1.4 Model Improvement For K-Means</h3>

# %% [markdown]
# <p>In this sub-section, I will be tuning the hyperparameter of K-Means so as to ensure the highest Silhouette Score is achieved. The metrics that will be used to evaluate the best parameters are Silhouette Score, Davies Bouldin Score and Calinski Harabasz Score in their respective order with Silhouette Score given priority. The formula for each of the metrics are listed below.</p>
#
# ---
#
# #### **Silhouette Score Formula**
#
# The silhouette score for a data point is given by:
#
# $$ S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))} $$
#
# Where:
#
# - $ S(i) $ is the silhouette score of point $ i $.
# - $ a(i) $ is the average distance between point $ i $ and other points in the same cluster.
# - $ b(i) $ is the average distance between point $ i $ and the nearest neighboring cluster.
#
# Interpretation:
# - $ S(i) \approx 1 $ → Well clustered
# - $ S(i) \approx 0 $ → Overlapping clusters
# - $ S(i) \approx -1 $ → Incorrect clustering
#
# ---
#
# #### **Davies-Bouldin (DB) Score Formula**
#
# The Davies-Bouldin index is given by:
#
# $$ DB = \frac{1}{k} \sum_{i=1}^{k} \max_{j \neq i} \left( \frac{\sigma_i + \sigma_j}{d_{ij}} \right) $$
#
# Where:
#
# - $ k $ is the number of clusters.
# - $ \sigma_i $ is the average distance of all points in cluster $ i $ to the cluster centroid.
# - $ d_{ij} $ is the Euclidean distance between centroids of clusters $ i $ and $ j $.
#
# Interpretation:
# - Lower **DB score** means better clustering (lower intra-cluster distance, higher inter-cluster separation).
#
# ---
#
# #### **Calinski-Harabasz (CH) Score Formula**
#
# The Calinski-Harabasz index is given by:
#
# $$ CH = \frac{Tr(B_k)}{Tr(W_k)} \times \frac{n - k}{k - 1} $$
#
# Where:
#
# - $ Tr(B_k) $ is the trace of the between-cluster scatter matrix.
# - $ Tr(W_k) $ is the trace of the within-cluster scatter matrix.
# - $ n $ is the total number of samples.
# - $ k $ is the number of clusters.
#
# Interpretation:
# - Higher **CH score** means better clustering (higher inter-cluster separation and compactness within clusters).
#
# ---
#
# <p>With the formula and metrics of evaluation indicated, I will proceed with hyperparameter tuning in the cell below.</p>

# %%
# ------------ Defining Of Parameters ----------- #
param_grid = {
    'init': ['k-means++', 'random'],
    'max_iter': [100, 200, 300, 400, 500, 1000],
    'n_init': [10, 15, 20, 25, 30, 50],
    'algorithm': ['lloyd', 'elkan']
}

# ------------ Initiating Best Score And Best Parameters ------------ #
best_score = -1
best_params = {}

# ---------- Initiate List To Store Results ----------- #
results = []

# ------------ Performing Grid Search ----------- #
for params in ParameterGrid(param_grid):
    kmeans = KMeans(n_clusters=6, random_state=42, **params)
    cluster_labels = kmeans.fit_predict(df_zscore[features_to_scale])
    
    # Computing Evaluation Metrics #
    silhouette_avg = silhouette_score(df_zscore[features_to_scale], cluster_labels)
    davies_bouldin = davies_bouldin_score(df_zscore[features_to_scale], cluster_labels)
    calinski_harabasz = calinski_harabasz_score(df_zscore[features_to_scale], cluster_labels)

    # Storing All Results #
    results.append({
        'init': params['init'],
        'max_iter': params['max_iter'],
        'n_init': params['n_init'],
        'algorithm': params['algorithm'],
        'silhouette_score': silhouette_avg,
        'davies_bouldin_score': davies_bouldin,
        'calinski_harabasz_score': calinski_harabasz
    })

    # Storing Best Parameter #
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_params = params
        best_params['silhouette_score'] = silhouette_avg

# ------------- Converting Results To DataFrame ----------- #
results_df_kmeans = pd.DataFrame(results)

# ------------ Displaying Of DataFrame ------------ #
results_df_kmeans.sort_values(by=["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"], ascending=False).head(1).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_1c8ad_row0_col1, #T_1c8ad_row0_col2, #T_1c8ad_row0_col4, #T_1c8ad_row0_col5, #T_1c8ad_row0_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_1c8ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c8ad_level0_col0" class="col_heading level0 col0" >init</th>
#       <th id="T_1c8ad_level0_col1" class="col_heading level0 col1" >max_iter</th>
#       <th id="T_1c8ad_level0_col2" class="col_heading level0 col2" >n_init</th>
#       <th id="T_1c8ad_level0_col3" class="col_heading level0 col3" >algorithm</th>
#       <th id="T_1c8ad_level0_col4" class="col_heading level0 col4" >silhouette_score</th>
#       <th id="T_1c8ad_level0_col5" class="col_heading level0 col5" >davies_bouldin_score</th>
#       <th id="T_1c8ad_level0_col6" class="col_heading level0 col6" >calinski_harabasz_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c8ad_level0_row0" class="row_heading level0 row0" >36</th>
#       <td id="T_1c8ad_row0_col0" class="data row0 col0" >random</td>
#       <td id="T_1c8ad_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_1c8ad_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_1c8ad_row0_col3" class="data row0 col3" >lloyd</td>
#       <td id="T_1c8ad_row0_col4" class="data row0 col4" >0.436898</td>
#       <td id="T_1c8ad_row0_col5" class="data row0 col5" >0.821283</td>
#       <td id="T_1c8ad_row0_col6" class="data row0 col6" >138.307770</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to see that with the hyperparameter tuning, the Silhouette Score increase by a slight margin. The scoring metrics indicated here will be used for evaluation as comparison to all the other models.</p>

# %% [markdown]
# <hr/>
# <h2>6.2  Agglomerative Clustering (Hierarchical Clustering)</h2>

# %% [markdown]
# <p>Agglomerative Clustering is a hierarchical clustering algorithm that recursively merges data points into a hierarchical tree (dendrogram). I have listed the strengths and weaknesses of Agglomerative Clustering  below.</p>
# <br/>
# <span style="color:green"><p><strong><u>Strengths</u></strong></p></span>
# <ul>
#     <li>No Need To Predefine K</li>
#     <li>Able To Capture Hierarchical Structure</li>
#     <li>Not Sensitive To Initialisation</li>
#     <li>Able To Handle Non-Speherical Clusters</li>
# </ul>
# <span style="color:red"><p><strong><u>Weaknesses</u></strong></p></span>
# <ul>
#     <li>Computationally Expensive</li>
#     <li>Difficult To Scale</li>
#     <li>Difficult To Adjust Once Merged</li>
# </ul>
# <br/>
# <p>With the context of the Strengths and Weaknesses of Agglomerative Clusering in mind, I will proceed to find the optimal k-cluster in the next sub-section.</p>

# %% [markdown]
# <hr/>
# <h3>6.2.1 Deciding Best Scaling For Agglomerative Clustering</h3>

# %% [markdown]
# <p>I conducted 2 methods of Scaling previously which are the Z-Score Standardisation and the Min-Max Scaling. These 2 methods utilised different methods of adjusting the Numerical Value which was stated previosuly. I will be comparing the Silhouette Score of the Min-Max Scaling Data and the Z-Score Standardisation Data. The formula for Silhouette Score have been indicated below.</p>
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Where:**
# - $S(i)$ → Silhouette Score of point $i$
# - $a(i)$ → Average distance between point $i$ and other points in the same cluster
# - $b(i)$ → Average distance between point $i$ and the nearest neighboring cluster
# - $-1 \leq S(i) \leq 1$, where:
#   - $S(i)$ close to **1** → Well clustered
#   - $S(i)$ close to **0** → Overlapping clusters
#   - $S(i)$ close to **-1** → Incorrect clustering
#
# <br/>
# <p>With the formula listed, I will proceed to plot out the Graphs to identify the Best Scaling Method to use for Agglomerative Clustering.</p>

# %%
# ----------- Defining Range Of K-Cluster ----------- #
k_values = range(2, 11)

# ---------- Initiate List To Store Results ----------- #
silhouette_scores_zscore, silhouette_scores_minmax = [], []
davies_bouldin_zscore, davies_bouldin_minmax = [], []
calinski_harabasz_zscore, calinski_harabasz_minmax = [], []

# ------------ Defining Datasets For Comparison ----------- #
datasets = {'Z-Score Standardization': df_zscore, 'Min-Max Scaling': df_minmax}

# ------------- Performing Agglomerative Clustering ----------- #
for k in k_values:
    for scaling_method, df in datasets.items():
        # Apply Agglomerative Clustering #
        agg_clustering = AgglomerativeClustering(n_clusters=k, linkage='ward')
        df['Cluster'] = agg_clustering.fit_predict(df[features_to_scale])

        # Computing Clustering Evaluation Metrics #
        silhouette_avg = silhouette_score(df[features_to_scale], df['Cluster'])
        davies_bouldin = davies_bouldin_score(df[features_to_scale], df['Cluster'])
        calinski_harabasz = calinski_harabasz_score(df[features_to_scale], df['Cluster'])

        # Store Metrics in Respective Lists #
        if scaling_method == 'Z-Score Standardization':
            silhouette_scores_zscore.append(silhouette_avg)
            davies_bouldin_zscore.append(davies_bouldin)
            calinski_harabasz_zscore.append(calinski_harabasz)
        else:
            silhouette_scores_minmax.append(silhouette_avg)
            davies_bouldin_minmax.append(davies_bouldin)
            calinski_harabasz_minmax.append(calinski_harabasz)

# ----------- Plot Silhouette Score For Comparison ---------- #
plt.figure(figsize=(14, 5))
plt.plot(k_values, silhouette_scores_zscore, marker='o', linestyle='--', color='b', label="Z-Score Standardization")
plt.plot(k_values, silhouette_scores_minmax, marker='o', linestyle='--', color='r', label="Min-Max Scaling")

# ---------- Labels And Titles ----------- #
plt.xlabel('Number of Clusters (k)', fontsize=12)
plt.ylabel('Silhouette Score', fontsize=12)
plt.title('Silhouette Score for Agglomerative Clustering', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True)

# ---------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output to the Line Plot for the Silhouette Score, for which I am able to see that the Min-Max has a lower Silhouette Score compared to Z-Score Standardisation. The observations and conclusion are listed below.</p>
# <br/>
# <p><strong><u>Min-Max Scaling</u></strong></p>
# <ul>
#     <li>Silhouette Score: Min-Max Scaling has a moderate Silhouette Score, peaking at around 0.42 for 6 Clusters.</li>
# </ul>
# <p><strong><u>Z-Score Standardisation</u></strong></p>
# <ul>
#     <li>Silhouette Score: Z-Score Standardisation has a higher Silhouette Score, peaking around 0.4 for 6 Clusters.</li>
# </ul>
# <p><strong><u>Conclusion</u></strong></p>
# <ul>
#     <li>Scaling Method To Use: Z-Score Standardisation.</li>
#     <li>Reason: Performed better in Silhouette Score than Min-Max Scaling.</li>
# </ul>
# <p>With the observation and conclusion listed out, I will proceed to find the Optimal K-Clusters and Compare the PCA results with the Original Data.</p>

# %% [markdown]
# <hr/>
# <h3>6.2.2 Finding Optimal K-Clusters And Reducing Dimensions</h3>

# %% [markdown]
# <p>Although Agglomerative Clustering does not require a k-cluser to be predefined, I will still be utilising the Sillhouette Score to find the Optimal k. The computation for the Sillhouette Score are indcated below. I will also be using Principal Component Analysis to reduce the dimensions of the Data to compare the results and determine if it improves the Silhouette Score. The formula for PCA is also indicated below.</p>
# <br/>
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Where:**
# - $S(i)$ → Silhouette Score of point $i$
# - $a(i)$ → Average distance between point $i$ and other points in the same cluster
# - $b(i)$ → Average distance between point $i$ and the nearest neighboring cluster
# - $-1 \leq S(i) \leq 1$, where:
#   - $S(i)$ close to **1** → Well clustered
#   - $S(i)$ close to **0** → Overlapping clusters
#   - $S(i)$ close to **-1** → Incorrect clustering
#
# $$
# Z = X W
# $$
#
# **Where:**
# - $ Z $ is the transformed data in the new principal component space.
# - $ X $ is the original data matrix (centered by subtracting the mean).
# - $ W $ is the matrix of eigenvectors (principal components).
#
# $$
# C = \frac{1}{n} X^T X
# $$
#
# **Where:**
# - $ C $ is the covariance matrix of $ X $.
# - $ n $ is the number of samples.
#
# $$
# C W = \lambda W
# $$
#
# **Where:**
# - $ \lambda $ are the eigenvalues.
# - $ W $ are the corresponding eigenvectors (principal components).
# <br/>
# <p>With the formulas listed, I will proceed to plot the Line Graph and conduct PCA in the cell below so as to identify the optimal K-Cluster.</p>

# %%
# ----------- Defining Range Of K-Clusters ----------- #
k_values = range(2, 11)

# ----------- Applying PCA ----------- #
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_zscore[features_to_scale])

# ----------- Initiating List To Store Silhouettes Score ----------- #
silhouette_scores_original = []
silhouette_scores_pca = []

# ----------- Computing Clustering Metrics ----------- #
for k in k_values:
    # Agglomerative Clustering On Original Data #
    ac_original = AgglomerativeClustering(n_clusters=k, linkage='ward')
    cluster_labels_original = ac_original.fit_predict(df_zscore[features_to_scale])
    silhouette_scores_original.append(silhouette_score(df_zscore[features_to_scale], cluster_labels_original))

    # Agglomerative Clustering On PCA Data #
    ac_pca = AgglomerativeClustering(n_clusters=k, linkage='ward')
    cluster_labels_pca = ac_pca.fit_predict(pca_result)
    silhouette_scores_pca.append(silhouette_score(pca_result, cluster_labels_pca))

# ----------- Defining Subplots ----------- #
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ----------- Plotting Silhouette Scores Line Graph ----------- #
axes[0].plot(k_values, silhouette_scores_original, marker='o', linestyle='--', color='blue', label="Original")
axes[0].plot(k_values, silhouette_scores_pca, marker='o', linestyle='--', color='green', label="PCA")
axes[0].set_xlabel('Number of Clusters (k)', fontsize=12)
axes[0].set_ylabel('Silhouette Score', fontsize=12)
axes[0].set_title('Silhouette Score for Original and PCA', fontsize=14, fontweight='bold')
axes[0].legend()
axes[0].grid(True)

# ----------- Plotting Bar Plot For Best K-Cluster ----------- #
best_k = 6
axes[1].bar(['Original', 'PCA'], [silhouette_scores_original[best_k-2], silhouette_scores_pca[best_k-2]], color=['blue', 'green'])
axes[1].set_xlabel('Dimensionality Reduction Method', fontsize=12)
axes[1].set_ylabel('Silhouette Score', fontsize=12)
axes[1].set_title(f'Silhouette Score for k={best_k}', fontsize=14, fontweight='bold')
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# ----------- Displaying Plot ----------- #
plt.tight_layout()
plt.show()

# %% [markdown]
# <p>With reference to the output of the Line Graph showing the Silhouette Score for the Optimal k, I am able to come to the conclusion that the Optimal K is 6. The observation for each of the method respectively have been indicated below.</p>
# <br/>
# <p><strong><u>Sihouette Method</u></strong></p>
# <ul>
#     <li>At k = 6, the Silhoutte Score peaked the highest at around 0.42.</li>
# </ul>
# <p><strong><u>Dimension Reduction</u></strong></p>
# <ul>
#     <li>Use Orginal Data due to higher Silhouette Score.</li>
# </ul>
# <br/>
# <p>Therefore, with the observations laid out and the ideal cluster of 6 determined, I will proceed to clustering using Agglomerative Clustering.</p>

# %% [markdown]
# <hr/>
# <h3>6.2.3 Conducting Agglomerative Clustering And Plotting Dendrogram</h3>

# %% [markdown]
# <p>After determining the Optimal K-Clusters, I will proceed to conduct the clustering using the Agglomerative Clustering in the cell below and subsequently plot out the Dendrogram to see where we cut off for the 6 Clusters. The Dendrogram will be plotted using Euclidean Distance for which the formula is listed below.</p>
#
# The Euclidean distance between two points in an **n-dimensional space** is given by:
#
# $$ d(A, B) = \sqrt{\sum_{i=1}^{n} (A_i - B_i)^2} $$
#
# Where:
#
# - $ d(A, B) $ is the Euclidean distance between points $ A $ and $ B $.
# - $ A_i, B_i $ are the coordinates of the points in **n-dimensional space**.
# - $ n $ is the number of dimensions.
#
# For **2D space**, the formula simplifies to:
#
# $$ d(A, B) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2} $$
#
# For **3D space**, the formula extends to:
#
# $$ d(A, B) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2 + (z_2 - z_1)^2} $$
#
# **Interpretation**:
# - The smaller the distance, the closer the points are to each other.
# - It is widely used in clustering, nearest neighbor searches, and distance-based algorithms.
# <br/>
# <p>With the formula listed, I will proceed to conduct the clustering in the cell below.</p>

# %%
# ---------- Defining Optimal K-Clusters ----------- #
optimal_k = 6

# ----------- Applying Agglomerative Clustering ----------- #
agg_clustering = AgglomerativeClustering(n_clusters=optimal_k, linkage='ward')
df_zscore['Cluster'] = agg_clustering.fit_predict(df_zscore[features_to_scale])

# ----------- Plot Dendrogram ----------- #
plt.figure(figsize=(12, 6))
dendrogram = sch.dendrogram(sch.linkage(df_zscore[features_to_scale], method='ward'))

# ----------- Titles And Labels ----------- #
plt.title('Dendrogram for Agglomerative Clustering')
plt.xlabel('Data Points')
plt.ylabel('Euclidean Distance')
plt.grid(True)

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Dendrogram above, I am able to see that for the k-cluster of 6, we cut off the Dendrogram at around 5.5. This is an ideal distance as seen from the Dendrogram as the distance was getting shorter and shorter after 5.5.</p>

# %% [markdown]
# <hr/>
# <h3>6.2.4 Visualising Clusters Using t-SNE</h3>

# %% [markdown]
# <p>After finding the Optimal k-Cluster, I will proceed to visualise the Clusters by reducing the Dimensions using t-SNE and subsequently using a Scatterplot to viusalise the 6 Clusters. t-SNE allows us to reduce the dimensions into 2 dimensions to allow for a better visualisation. The formula for t-SNE is indicated below.</p>
#
# The probability distribution in high-dimensional space is defined as:
#
# $$ P_{j|i} = \frac{\exp(-||x_i - x_j||^2 / 2\sigma_i^2)}{\sum_{k \neq i} \exp(-||x_i - x_k||^2 / 2\sigma_i^2)} $$
#
# Where:
#
# - $ P_{j|i} $ is the conditional probability that point $ x_j $ is chosen as a neighbor of point $ x_i $.
# - $ x_i, x_j $ are high-dimensional data points.
# - $ \sigma_i $ is the bandwidth of the Gaussian kernel for point $ x_i $.
#
# The probability distribution in low-dimensional space is:
#
# $$ Q_{j|i} = \frac{(1 + ||y_i - y_j||^2)^{-1}}{\sum_{k \neq i} (1 + ||y_i - y_k||^2)^{-1}} $$
#
# Where:
#
# - $ Q_{j|i} $ is the conditional probability in the lower-dimensional space.
# - $ y_i, y_j $ are the mapped points in the lower-dimensional space.
#
# The Kullback-Leibler (KL) divergence, which t-SNE minimizes, is given by:
#
# $$ KL(P||Q) = \sum_i \sum_j P_{ij} \log \frac{P_{ij}}{Q_{ij}} $$
#
# Where:
#
# - $ KL(P||Q) $ measures the difference between the high-dimensional and low-dimensional distributions.
# - $ P_{ij} $ and $ Q_{ij}
# - $ are the symmetric joint probabilities.
#
# <br/>
# <p>With the formula indicated, I will proceed to conduct the visualisation in the cell below.</p>

# %%
# ---------- Defining Optimal K-Clusters ----------- #
optimal_k = 6

# ----------- Computing Clustering evaluation Metrics ------------ #
silhouette_avg = silhouette_score(df_zscore[features_to_scale], df_zscore['Cluster'])
davies_bouldin = davies_bouldin_score(df_zscore[features_to_scale], df_zscore['Cluster'])
calinski_harabasz = calinski_harabasz_score(df_zscore[features_to_scale], df_zscore['Cluster'])

# ------------- Storing Results In DataFrame ----------- #
clustering_metrics = pd.DataFrame({
    'Metric': ['Silhouette Score', 'Davies-Bouldin Score', 'Calinski-Harabasz Score'],
    'Value': [silhouette_avg, davies_bouldin, calinski_harabasz]
})

# -------------- Applying t-SNE For Visualisation ------------- #
tsne = TSNE(n_components=2, random_state=42, perplexity=30, learning_rate=200)
tsne_results = tsne.fit_transform(df_zscore[features_to_scale])

# ------------ Adding t-SNE Results Into DataFrame ------------ #
df_zscore['TSNE1'] = tsne_results[:, 0]
df_zscore['TSNE2'] = tsne_results[:, 1]

# ------------ Visualising t-SNE Clusters ------------ #
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_zscore['TSNE1'], y=df_zscore['TSNE2'], hue=df_zscore['Cluster'], 
                palette='viridis', alpha=0.7, edgecolor='black')

# ------------ Title And Labels ------------ #
plt.xlabel('t-SNE Component 1', fontsize=12)
plt.ylabel('t-SNE Component 2', fontsize=12)
plt.title(f'Agglomerative Clustering Visualization with t-SNE (k={optimal_k})', fontsize=14, fontweight='bold')
plt.legend(title="Cluster")
plt.grid(True)

# ------------ Displaying Plot ------------ #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Visualisation of Clusters above, I am able to observe that the clusters are generally well-clustered with multiple exceptions. I will proceed to test out the other method of clustering and conduct cross referencing on the quality of clustering.</p>

# %% [markdown]
# <hr/>
# <h3>6.2.5 Model Improvement For Agglomerative Clustering</h3>

# %% [markdown]
# <p>In this sub-section, I will be tuning the hyperparameter of Agglomerative Clustering so as to ensure the highest Silhouette Score is achieved. The metrics that will be used to evaluate the best parameters are Silhouette Score, Davies Bouldin Score and Calinski Harabasz Score in their respective order with Silhouette Score given priority. The formula for each of the metrics are listed below.</p>
#
# ---
#
# #### **Silhouette Score Formula**
#
# The silhouette score for a data point is given by:
#
# $$ S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))} $$
#
# Where:
#
# - $ S(i) $ is the silhouette score of point $ i $.
# - $ a(i) $ is the average distance between point $ i $ and other points in the same cluster.
# - $ b(i) $ is the average distance between point $ i $ and the nearest neighboring cluster.
#
# Interpretation:
# - $ S(i) \approx 1 $ → Well clustered
# - $ S(i) \approx 0 $ → Overlapping clusters
# - $ S(i) \approx -1 $ → Incorrect clustering
#
# ---
#
# #### **Davies-Bouldin (DB) Score Formula**
#
# The Davies-Bouldin index is given by:
#
# $$ DB = \frac{1}{k} \sum_{i=1}^{k} \max_{j \neq i} \left( \frac{\sigma_i + \sigma_j}{d_{ij}} \right) $$
#
# Where:
#
# - $ k $ is the number of clusters.
# - $ \sigma_i $ is the average distance of all points in cluster $ i $ to the cluster centroid.
# - $ d_{ij} $ is the Euclidean distance between centroids of clusters $ i $ and $ j $.
#
# Interpretation:
# - Lower **DB score** means better clustering (lower intra-cluster distance, higher inter-cluster separation).
#
# ---
#
# #### **Calinski-Harabasz (CH) Score Formula**
#
# The Calinski-Harabasz index is given by:
#
# $$ CH = \frac{Tr(B_k)}{Tr(W_k)} \times \frac{n - k}{k - 1} $$
#
# Where:
#
# - $ Tr(B_k) $ is the trace of the between-cluster scatter matrix.
# - $ Tr(W_k) $ is the trace of the within-cluster scatter matrix.
# - $ n $ is the total number of samples.
# - $ k $ is the number of clusters.
#
# Interpretation:
# - Higher **CH score** means better clustering (higher inter-cluster separation and compactness within clusters).
#
# ---
#
# <p>With the formula and metrics of evaluation indicated, I will proceed with hyperparameter tuning in the cell below.</p>

# %%
# ------------ Defining Of Parameters ----------- #
param_grid = {
    'n_clusters': [6],
    'linkage': ['ward', 'complete', 'average', 'single'],
    'distance_threshold': [None],
    'compute_full_tree': [True, False]
}

# ----------- Initiating Best Score And Best Parameters ----------- #
best_score = -1
best_params = {}

# ---------- Initiate List To Store Results ----------- #
results = []

# ------------ Performing Grid Search ----------- #
for params in ParameterGrid(param_grid):
    # Ensure 'ward' Linkage Does Not Require Distance #
    if params['linkage'] == 'ward':
        agg_clustering = AgglomerativeClustering(**params)
    else:
        agg_clustering = AgglomerativeClustering(**params, metric='euclidean')

    cluster_labels = agg_clustering.fit_predict(df_zscore[features_to_scale])
    
    # Computing Evaluation Metrics #
    silhouette_avg = silhouette_score(df_zscore[features_to_scale], cluster_labels)
    davies_bouldin = davies_bouldin_score(df_zscore[features_to_scale], cluster_labels)
    calinski_harabasz = calinski_harabasz_score(df_zscore[features_to_scale], cluster_labels)

    # Storing All Results #
    results.append({
        'n_clusters': params['n_clusters'],
        'linkage': params['linkage'],
        'compute_full_tree': params['compute_full_tree'],
        'silhouette_score': silhouette_avg,
        'davies_bouldin_score': davies_bouldin,
        'calinski_harabasz_score': calinski_harabasz
    })

    # Store Best Parameters Based On Silhouette Score #
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_params = params
        best_params['silhouette_score'] = silhouette_avg

# ----------- Converting Results To DataFrame ------------ #
results_df_ac = pd.DataFrame(results)

# ----------- Displaying DataFrame ----------- #
results_df_ac.sort_values(by=["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"], ascending=False).head(1).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_35746_row0_col0, #T_35746_row0_col3, #T_35746_row0_col4, #T_35746_row0_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_35746">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35746_level0_col0" class="col_heading level0 col0" >n_clusters</th>
#       <th id="T_35746_level0_col1" class="col_heading level0 col1" >linkage</th>
#       <th id="T_35746_level0_col2" class="col_heading level0 col2" >compute_full_tree</th>
#       <th id="T_35746_level0_col3" class="col_heading level0 col3" >silhouette_score</th>
#       <th id="T_35746_level0_col4" class="col_heading level0 col4" >davies_bouldin_score</th>
#       <th id="T_35746_level0_col5" class="col_heading level0 col5" >calinski_harabasz_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35746_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35746_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_35746_row0_col1" class="data row0 col1" >ward</td>
#       <td id="T_35746_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_35746_row0_col3" class="data row0 col3" >0.425948</td>
#       <td id="T_35746_row0_col4" class="data row0 col4" >0.844619</td>
#       <td id="T_35746_row0_col5" class="data row0 col5" >124.891588</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to see that with the hyperparameter tuning, the Silhouette Score increase by a slight margin. The scoring metrics indicated here will be used for evaluation as comparison to all the other models.</p>

# %% [markdown]
# <hr/>
# <h2>6.3 DBSCAN (Density-Based Spatial Clustering of Applications with Noise)</h2>

# %% [markdown]
# <p>DBSCAN is a density-based clustering algorithm that groups data points based on density. It also works best with arbitrary-shaped clusters. I have listed the strengths and weaknesses of DBSCAN below.</p>
# <br/>
# <span style="color:green"><p><strong><u>Strengths</u></strong></p></span>
# <ul>
#     <li>K Do Not Need To Be Predefined</li>
#     <li>Handles Arbitrary Shaped Clusters</li>
#     <li>Able To Handle Data With Varying Densities</li>
# </ul>
# <span style="color:red"><p><strong><u>Weaknesses</u></strong></p></span>
# <ul>
#     <li>Extremely Sensitive To Parameters</li>
#     <li>Fails For Varying Density Clusters</li>
#     <li>Difficult Interpretation</li>
# </ul>
# <br/>
# <p>With the context of the Strengths and Weaknesses of DBSCAN in mind, I will proceed to find the optimal EPS in the next sub-section.</p>

# %% [markdown]
# <hr/>
# <h3>6.3.1 Deciding Best Scaling For DBSCAN</h3>

# %% [markdown]
# <p>I conducted 2 methods of Scaling previously which are the Z-Score Standardisation and the Min-Max Scaling. These 2 methods utilised different methods of adjusting the Numerical Value which was stated previosuly. I will be comparing the Silhouette Score of the Min-Max Scaling Data and the Z-Score Standardisation Data. The formula for Silhouette Score have been indicated below.</p>
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Where:**
# - $S(i)$ → Silhouette Score of point $i$
# - $a(i)$ → Average distance between point $i$ and other points in the same cluster
# - $b(i)$ → Average distance between point $i$ and the nearest neighboring cluster
# - $-1 \leq S(i) \leq 1$, where:
#   - $S(i)$ close to **1** → Well clustered
#   - $S(i)$ close to **0** → Overlapping clusters
#   - $S(i)$ close to **-1** → Incorrect clustering
#
# <br/>
# <p>With the formula listed, I will proceed to plot out the Graphs to identify the Best Scaling Method to use for DBSCAN.</p>

# %%
# ---------- Defining Range Of ESP Values ----------- #
eps_values = np.arange(0.1, 1.1, 0.1)

# ---------- Initiate List To Store Results ----------- #
silhouette_scores_zscore = []
silhouette_scores_minmax = []

# ------------ Defining Datasets For Comparison ----------- #
datasets = {'Z-Score Standardization': df_zscore.copy(), 'Min-Max Scaling': df_minmax.copy()}

# ------------ Performing DBSCAN ----------- #
for eps in eps_values:
    for scaling_method, df in datasets.items():
        # Applying DBSCAN #
        dbscan = DBSCAN(eps=eps, min_samples=3, metric='euclidean')
        df['Cluster'] = dbscan.fit_predict(df[features_to_scale])

        # Removing Noise Points (-1) Before Evaluation #
        filtered_df = df[df['Cluster'] != -1]
        if len(set(filtered_df['Cluster'])) > 1:
            silhouette_avg = silhouette_score(filtered_df[features_to_scale], filtered_df['Cluster'])
        else:
            silhouette_avg = np.nan

        # Store Metrics In Respective List #
        if scaling_method == 'Z-Score Standardization':
            silhouette_scores_zscore.append(silhouette_avg)
        else:
            silhouette_scores_minmax.append(silhouette_avg)

# ----------- Putting Results Into DataFrame ---------- #
silhouette_df = pd.DataFrame({
    'eps': eps_values,
    'Silhouette_ZScore': silhouette_scores_zscore,
    'Silhouette_MinMax': silhouette_scores_minmax
})

# ------------ Plotting Line Graph For DBSCAN ----------- #
plt.figure(figsize=(14, 5))
plt.plot(silhouette_df['eps'], silhouette_df['Silhouette_ZScore'], marker='o', linestyle='--', color='b', label="Z-Score Standardization")
plt.plot(silhouette_df['eps'], silhouette_df['Silhouette_MinMax'], marker='o', linestyle='--', color='r', label="Min-Max Scaling")

# ------------ Titles And Labels ----------- #
plt.xlabel('Epsilon (eps)', fontsize=12)
plt.ylabel('Silhouette Score', fontsize=12)
plt.title('Silhouette Score for DBSCAN - Z-Score vs Min-Max Scaling', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True)

# ------------ Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output to the Line Plot for the Silhouette Score, for which I am able to see that the Min-Max has a lower Silhouette Score compared to Z-Score Standardisation. The observations and conclusion are listed below.</p>
# <br/>
# <p><strong><u>Min-Max Scaling</u></strong></p>
# <ul>
#     <li>Silhouette Score: Min-Max Scaling has a moderate Silhouette Score, at around 0.45 at 0.1 Epsilon but afterwards being voided.</li>
# </ul>
# <p><strong><u>Z-Score Standardisation</u></strong></p>
# <ul>
#     <li>Silhouette Score: Min-Max Scaling has a moderate Consistent Silhouette Score, at around 0.25 at 0.5 Epsilon.</li>
# </ul>
# <p><strong><u>Conclusion</u></strong></p>
# <ul>
#     <li>Scaling Method To Use: Z-Score Standardisation.</li>
#     <li>Reason: Performed better in Silhouette Score than Min-Max Scaling.</li>
# </ul>
# <p>With the observation and conclusion listed out, I will proceed to find the Optimal K-Clusters and Compare the PCA results with the Original Data.</p>

# %% [markdown]
# <hr/>
# <h3>6.3.2 Finding Optimal Episilon And Reducing Dimensions</h3>

# %% [markdown]
# <p>Although DBSCAN does not require a k-cluser to be predefined, I will still be utilising the Sillhouette Score to find the Optimal Episilon. The computation for the Sillhouette Score are indcated below. I will also be using Principal Component Analysis to reduce the dimensions of the Data to compare the results and determine if it improves the Silhouette Score. The formula for PCA is also indicated below.</p>
# <br/>
#
# $$
# S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Where:**
# - $S(i)$ → Silhouette Score of point $i$
# - $a(i)$ → Average distance between point $i$ and other points in the same cluster
# - $b(i)$ → Average distance between point $i$ and the nearest neighboring cluster
# - $-1 \leq S(i) \leq 1$, where:
#   - $S(i)$ close to **1** → Well clustered
#   - $S(i)$ close to **0** → Overlapping clusters
#   - $S(i)$ close to **-1** → Incorrect clustering
#
# $$
# Z = X W
# $$
#
# **Where:**
# - $ Z $ is the transformed data in the new principal component space.
# - $ X $ is the original data matrix (centered by subtracting the mean).
# - $ W $ is the matrix of eigenvectors (principal components).
#
# $$
# C = \frac{1}{n} X^T X
# $$
#
# **Where:**
# - $ C $ is the covariance matrix of $ X $.
# - $ n $ is the number of samples.
#
# $$
# C W = \lambda W
# $$
#
# **Where:**
# - $ \lambda $ are the eigenvalues.
# - $ W $ are the corresponding eigenvectors (principal components).
# <br/>
# <p>With the formulas listed, I will proceed to plot the Line Graph and conduct PCA in the cell below so as to identify the optimal Epsilon.</p>

# %%
# ------------ Defining Range Of EPS Values ---------- #
eps_values = np.arange(0.1, 1.1, 0.1)

# ----------- Applying PCA ----------- #
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_zscore[features_to_scale])

# ----------- Initiating List To Store Results ------------ #
silhouette_scores_original = []
silhouette_scores_pca = []

# ------------ Computing Clustering Metrics ----------- #
for eps in eps_values:
    # DBSCAN On Original Data #
    dbscan_original = DBSCAN(eps=eps, min_samples=5, metric='euclidean')
    cluster_labels_original = dbscan_original.fit_predict(df_zscore[features_to_scale])
    if len(set(cluster_labels_original)) > 1:
        silhouette_scores_original.append(silhouette_score(df_zscore[features_to_scale], cluster_labels_original))
    else:
        silhouette_scores_original.append(np.nan)

    # DBSCAN On PCA Data #
    dbscan_pca = DBSCAN(eps=eps, min_samples=5, metric='euclidean')
    cluster_labels_pca = dbscan_pca.fit_predict(pca_result)
    if len(set(cluster_labels_pca)) > 1:
        silhouette_scores_pca.append(silhouette_score(pca_result, cluster_labels_pca))
    else:
        silhouette_scores_pca.append(np.nan)

# ----------- Defining Subplots ----------- #
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ---------- Plotting Line Graph For Silhouette Score ----------- #
axes[0].plot(eps_values, silhouette_scores_original, marker='o', linestyle='--', color='blue', label="Original")
axes[0].plot(eps_values, silhouette_scores_pca, marker='o', linestyle='--', color='green', label="PCA")
axes[0].set_xlabel('Epsilon (eps)', fontsize=12)
axes[0].set_ylabel('Silhouette Score', fontsize=12)
axes[0].set_title('Silhouette Score for Original and PCA', fontsize=14, fontweight='bold')
axes[0].legend()
axes[0].grid(True)

# ------------ Plotting Bar Plot For Best ESP Score ----------- #
best_eps = 0.5
axes[1].bar(['Original', 'PCA'], [silhouette_scores_original[int(best_eps * 10 - 1)], silhouette_scores_pca[int(best_eps * 10 - 1)]], color=['blue', 'green'])
axes[1].set_xlabel('Dimensionality Reduction Method', fontsize=12)
axes[1].set_ylabel('Silhouette Score', fontsize=12)
axes[1].set_title(f'Silhouette Score for eps={best_eps}', fontsize=14, fontweight='bold')
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# ----------- Displaying Plot ------------- #
plt.tight_layout()
plt.show()

# %% [markdown]
# <p>With reference to the output of the Line Graph showing the Silhouette Score for the Optimal Epsilon, I am able to come to the conclusion that the Optimal Epsilon is 0.9. The observation for each of the method respectively have been indicated below.</p>
# <br/>
# <p><strong><u>Sihouette Method</u></strong></p>
# <ul>
#     <li>At eps = 0.9, the Silhoutte Score peaked at around 0.28.</li>
# </ul>
# <p><strong><u>Dimension Reduction</u></strong></p>
# <ul>
#     <li>Use Orginal Data due to no Consistency in PCA Data.</li>
# </ul>
# <br/>
# <p>Therefore, with the observations laid out and the ideal epsilon of 0.9 is determined, I will proceed to clustering using DBSCAN.</p>

# %% [markdown]
# <hr/>
# <h3>6.3.3 Visualising Clusters Using t-SNE</h3>

# %% [markdown]
# <p>After finding the Optimal Epsilon, I will proceed to visualise the Clusters by reducing the Dimensions using t-SNE and subsequently using a Scatterplot to viusalise the Clustering at 0.9 Epsilon. t-SNE allows us to reduce the dimensions into 2 dimensions to allow for a better visualisation. The formula for t-SNE is indicated below.</p>
#
# The probability distribution in high-dimensional space is defined as:
#
# $$ P_{j|i} = \frac{\exp(-||x_i - x_j||^2 / 2\sigma_i^2)}{\sum_{k \neq i} \exp(-||x_i - x_k||^2 / 2\sigma_i^2)} $$
#
# Where:
#
# - $ P_{j|i} $ is the conditional probability that point $ x_j $ is chosen as a neighbor of point $ x_i $.
# - $ x_i, x_j $ are high-dimensional data points.
# - $ \sigma_i $ is the bandwidth of the Gaussian kernel for point $ x_i $.
#
# The probability distribution in low-dimensional space is:
#
# $$ Q_{j|i} = \frac{(1 + ||y_i - y_j||^2)^{-1}}{\sum_{k \neq i} (1 + ||y_i - y_k||^2)^{-1}} $$
#
# Where:
#
# - $ Q_{j|i} $ is the conditional probability in the lower-dimensional space.
# - $ y_i, y_j $ are the mapped points in the lower-dimensional space.
#
# The Kullback-Leibler (KL) divergence, which t-SNE minimizes, is given by:
#
# $$ KL(P||Q) = \sum_i \sum_j P_{ij} \log \frac{P_{ij}}{Q_{ij}} $$
#
# Where:
#
# - $ KL(P||Q) $ measures the difference between the high-dimensional and low-dimensional distributions.
# - $ P_{ij} $ and $ Q_{ij}
# - $ are the symmetric joint probabilities.
#
# <br/>
# <p>With the formula indicated, I will proceed to conduct the visualisation in the cell below.</p>

# %%
# ---------- Define Optimal Episilon ----------- #
optimal_eps = 0.9
min_samples = 3

# ---------- Applying DBSCAN On Data ----------- #
dbscan = DBSCAN(eps=optimal_eps, min_samples=min_samples, metric='euclidean')
df_zscore['Cluster'] = dbscan.fit_predict(df_zscore.drop(columns=['TSNE1', 'TSNE2'], errors='ignore'))

# -------------- Applying t-SNE For Visualisation ------------- #
tsne = TSNE(n_components=2, random_state=42, perplexity=10, learning_rate=50)
tsne_results = tsne.fit_transform(df_zscore)

# ------------ Adding t-SNE Results Into DataFrame ------------ #
df_zscore['TSNE1'] = tsne_results[:, 0]
df_zscore['TSNE2'] = tsne_results[:, 1]

# ------------ Visualising t-SNE Clusters ------------ #
plt.figure(figsize=(15, 9))
sns.scatterplot(x=df_zscore['TSNE1'], y=df_zscore['TSNE2'], hue=df_zscore['Cluster'],
                palette='Set1', alpha=0.7, edgecolor='black')

# ------------ Title And Labels ------------ #
plt.xlabel('t-SNE Component 1', fontsize=12)
plt.ylabel('t-SNE Component 2', fontsize=12)
plt.title(f'Visualization of DBSCAN Clusters using t-SNE (eps={optimal_eps}, min_samples={min_samples})',
          fontsize=14, fontweight='bold')
plt.legend(title="Cluster")
plt.grid(True)

# ------------ Displaying Plot ------------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Visualisation of Clusters above, I am able to observe that the clusters are poorly clustered with a very minimal amount exceptions. I will proceed to test out the other method of clustering and conduct cross referencing on the quality of clustering.</p>

# %% [markdown]
# <hr/>
# <h3>6.3.4 Model Improvement For DBSCAN</h3>

# %% [markdown]
# <p>In this sub-section, I will be tuning the hyperparameter of DBSCAN so as to ensure the highest Silhouette Score is achieved. The metrics that will be used to evaluate the best parameters are Silhouette Score, Davies Bouldin Score and Calinski Harabasz Score in their respective order with Silhouette Score given priority. The formula for each of the metrics are listed below.</p>
#
# ---
#
# #### **Silhouette Score Formula**
#
# The silhouette score for a data point is given by:
#
# $$ S(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))} $$
#
# Where:
#
# - $ S(i) $ is the silhouette score of point $ i $.
# - $ a(i) $ is the average distance between point $ i $ and other points in the same cluster.
# - $ b(i) $ is the average distance between point $ i $ and the nearest neighboring cluster.
#
# Interpretation:
# - $ S(i) \approx 1 $ → Well clustered
# - $ S(i) \approx 0 $ → Overlapping clusters
# - $ S(i) \approx -1 $ → Incorrect clustering
#
# ---
#
# #### **Davies-Bouldin (DB) Score Formula**
#
# The Davies-Bouldin index is given by:
#
# $$ DB = \frac{1}{k} \sum_{i=1}^{k} \max_{j \neq i} \left( \frac{\sigma_i + \sigma_j}{d_{ij}} \right) $$
#
# Where:
#
# - $ k $ is the number of clusters.
# - $ \sigma_i $ is the average distance of all points in cluster $ i $ to the cluster centroid.
# - $ d_{ij} $ is the Euclidean distance between centroids of clusters $ i $ and $ j $.
#
# Interpretation:
# - Lower **DB score** means better clustering (lower intra-cluster distance, higher inter-cluster separation).
#
# ---
#
# #### **Calinski-Harabasz (CH) Score Formula**
#
# The Calinski-Harabasz index is given by:
#
# $$ CH = \frac{Tr(B_k)}{Tr(W_k)} \times \frac{n - k}{k - 1} $$
#
# Where:
#
# - $ Tr(B_k) $ is the trace of the between-cluster scatter matrix.
# - $ Tr(W_k) $ is the trace of the within-cluster scatter matrix.
# - $ n $ is the total number of samples.
# - $ k $ is the number of clusters.
#
# Interpretation:
# - Higher **CH score** means better clustering (higher inter-cluster separation and compactness within clusters).
#
# ---
#
# <p>With the formula and metrics of evaluation indicated, I will proceed with hyperparameter tuning in the cell below.</p>

# %%
# ------------ Defining Parameter For Tuning ---------- #
param_grid = {
    'eps': [0.9],
    'min_samples': [3, 5, 7, 10],
    'metric': ['euclidean', 'manhattan'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# ------------ Initialising Best Parameter And Score ----------- #
best_score = -1
best_params = {}

# ------------ Initiating List For Results Storage ----------- #
results = []

# ----------- Perform Grid Search For DBSCAN ----------- #
for params in ParameterGrid(param_grid):
    dbscan = DBSCAN(**params)
    cluster_labels = dbscan.fit_predict(df_zscore[features_to_scale])
    
    # Remove Noise Points #
    filtered_df = df_zscore[cluster_labels != -1]
    if len(set(filtered_df['Cluster'])) > 1:  # Ensure at least 2 clusters exist
        silhouette_avg = silhouette_score(filtered_df[features_to_scale], filtered_df['Cluster'])
        davies_bouldin = davies_bouldin_score(filtered_df[features_to_scale], filtered_df['Cluster'])
        calinski_harabasz = calinski_harabasz_score(filtered_df[features_to_scale], filtered_df['Cluster'])
    else:
        silhouette_avg, davies_bouldin, calinski_harabasz = np.nan, np.nan, np.nan

    # Store All Results #
    results.append({
        'eps': params['eps'],
        'min_samples': params['min_samples'],
        'metric': params['metric'],
        'algorithm': params['algorithm'],
        'silhouette_score': silhouette_avg,
        'davies_bouldin_score': davies_bouldin,
        'calinski_harabasz_score': calinski_harabasz
    })

    # Storing Best Parameter Based On Silhouette Score #
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_params = params
        best_params['silhouette_score'] = silhouette_avg

# ------------ Convert Results To DataFrame ------------ #
results_df_dbscan = pd.DataFrame(results)

# ------------ Displaying DataFrame ------------ #
results_df_dbscan.sort_values(by=["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"], ascending=False).head(1).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_c5759_row0_col0, #T_c5759_row0_col1, #T_c5759_row0_col4, #T_c5759_row0_col5, #T_c5759_row0_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_c5759">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5759_level0_col0" class="col_heading level0 col0" >eps</th>
#       <th id="T_c5759_level0_col1" class="col_heading level0 col1" >min_samples</th>
#       <th id="T_c5759_level0_col2" class="col_heading level0 col2" >metric</th>
#       <th id="T_c5759_level0_col3" class="col_heading level0 col3" >algorithm</th>
#       <th id="T_c5759_level0_col4" class="col_heading level0 col4" >silhouette_score</th>
#       <th id="T_c5759_level0_col5" class="col_heading level0 col5" >davies_bouldin_score</th>
#       <th id="T_c5759_level0_col6" class="col_heading level0 col6" >calinski_harabasz_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5759_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_c5759_row0_col0" class="data row0 col0" >0.900000</td>
#       <td id="T_c5759_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_c5759_row0_col2" class="data row0 col2" >euclidean</td>
#       <td id="T_c5759_row0_col3" class="data row0 col3" >auto</td>
#       <td id="T_c5759_row0_col4" class="data row0 col4" >0.012085</td>
#       <td id="T_c5759_row0_col5" class="data row0 col5" >4.275562</td>
#       <td id="T_c5759_row0_col6" class="data row0 col6" >56.064419</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to see that with the hyperparameter tuning, the Silhouette Score increase by a slight margin. The scoring metrics indicated here will be used for evaluation as comparison to all the other models.</p>

# %% [markdown]
# <hr/>
# <h2>6.4 Model Comparison And Evaluation</h2>

# %% [markdown]
# <p>In this sub-section, I will be comparing the 3 different models that I have used and choose the best performing model to adopt and interpret. I will be comparing the metrics after the Hyperparameter tuning for each of the model. Subsequently, I will save the model and interpret the clustering so as to ensure that the model is beneficial to the stakeholder.</p>

# %% [markdown]
# <hr/>
# <h3>6.4.1 Identifying Best Model</h3>

# %% [markdown]
# <p>In this sub-section, I will be indentifying the best model amongst all the 3 models that I have tested. The best model is defined by having the highest Silhouette Score, Lowest Davies Bouldin Score and Highest Calinski Harabasz Score. The Best Model will then be used to visualise the Clustering another time before the saving of the model and subsequently, the interpretation of the clustering and its implications.</p>

# %%
# ----------- Extracting Best Results ----------- #
best_kmeans = results_df_kmeans.sort_values(
    by=["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"], 
    ascending=False
).head(1)[["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"]]

best_ac = results_df_ac.sort_values(
    by=["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"], 
    ascending=False
).head(1)[["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"]]

best_dbscan = results_df_dbscan.sort_values(
    by=["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"], 
    ascending=False
).head(1)[["silhouette_score", "davies_bouldin_score", "calinski_harabasz_score"]]

# ----------- Assigning Method As Index ------------ #
best_kmeans.index = ["K-Means"]
best_ac.index = ["Agglomerative Clustering"]
best_dbscan.index = ["DBSCAN"]

# ----------- Combining All Data Rows ---------- #
final_results_df = pd.concat([best_kmeans, best_ac, best_dbscan])

# ------------ Displaying DataFrame ----------- #
final_results_df.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_fc836_row0_col0, #T_fc836_row0_col2, #T_fc836_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fc836_row0_col1, #T_fc836_row2_col0, #T_fc836_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fc836_row1_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_fc836_row1_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_fc836_row1_col2 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fc836">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc836_level0_col0" class="col_heading level0 col0" >silhouette_score</th>
#       <th id="T_fc836_level0_col1" class="col_heading level0 col1" >davies_bouldin_score</th>
#       <th id="T_fc836_level0_col2" class="col_heading level0 col2" >calinski_harabasz_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc836_level0_row0" class="row_heading level0 row0" >K-Means</th>
#       <td id="T_fc836_row0_col0" class="data row0 col0" >0.436898</td>
#       <td id="T_fc836_row0_col1" class="data row0 col1" >0.821283</td>
#       <td id="T_fc836_row0_col2" class="data row0 col2" >138.307770</td>
#     </tr>
#     <tr>
#       <th id="T_fc836_level0_row1" class="row_heading level0 row1" >Agglomerative Clustering</th>
#       <td id="T_fc836_row1_col0" class="data row1 col0" >0.425948</td>
#       <td id="T_fc836_row1_col1" class="data row1 col1" >0.844619</td>
#       <td id="T_fc836_row1_col2" class="data row1 col2" >124.891588</td>
#     </tr>
#     <tr>
#       <th id="T_fc836_level0_row2" class="row_heading level0 row2" >DBSCAN</th>
#       <td id="T_fc836_row2_col0" class="data row2 col0" >0.012085</td>
#       <td id="T_fc836_row2_col1" class="data row2 col1" >4.275562</td>
#       <td id="T_fc836_row2_col2" class="data row2 col2" >56.064419</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to confirm that the model that is determined to be the best model is K-Means. This is due to it having the highest Silhouette Score, the lowest Davies Bouldin Score and the highest Calinski Harabasz Score. Therefore, I will proceed to utilise the K-Means Clustering Model for the interpretation.</p>

# %% [markdown]
# <hr/>
# <h3>6.4.2 Visualising Best Model Clustering</h3>

# %% [markdown]
# <p>With K-Means determined to be the best model, I will proceed to visualise the clustering quality of K-Means and determine if the clustering quality is satisfactory or should the hyperparameter be tuned further.</p>

# %%
# ------------ Define Parameters For K-Means ------------ #
kmeans = KMeans(
    n_clusters=6,
    init='random',
    max_iter=100,
    n_init=10,
    algorithm='lloyd',
    random_state=42
)

# ------------ Fit K-Means To Data ------------ #
df_zscore['Cluster'] = kmeans.fit_predict(df_zscore[features_to_scale])

# -------------- Applying t-SNE For Visualisation ------------- #
tsne = TSNE(n_components=2, random_state=42, perplexity=30, learning_rate=200)
tsne_results = tsne.fit_transform(df_zscore[features_to_scale])
df_zscore['TSNE1'] = tsne_results[:, 0]
df_zscore['TSNE2'] = tsne_results[:, 1]

# ----------- Visualise Clusters ----------- #
plt.figure(figsize=(12, 7))
sns.scatterplot(
    x=df_zscore['TSNE1'], y=df_zscore['TSNE2'], 
    hue=df_zscore['Cluster'], palette='viridis', alpha=0.7, edgecolor='black'
)
plt.xlabel('t-SNE Component 1', fontsize=12)
plt.ylabel('t-SNE Component 2', fontsize=12)
plt.title('K-Means Clustering Visualisation with t-SNE', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <p>With reference to the Clustering Visualisation above, I am able to see that generally, the clustering conducted by K-Means is satisfactory with a few exceptions. However, these exceptions are minimal, therefore, we are able to accept K-Means as our primary model.</p>

# %% [markdown]
# <hr/>
# <h3>6.4.3 Saving Of K-Means Model</h3>

# %% [markdown]
# <p>In this sub-section, I will be saving the K-Means Model and its parameter so as to prepare it for deployment and be used for clustering with other data.</p>

# %%
# ---------- Saving Of Model ---------- #
joblib.dump(kmeans, 'CA2-Saved-Models/kmeans_model.pkl')

# ---------- Confirmation Message ----------- #
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %% [markdown]
# <p>With reference to the confirmation message above, I am able to determined that the K-Means have been saved successfully and is ready for deployment.</p>

# %% [markdown]
# <hr/>
# <h1>7. Interpretation Of Clusters</h1>

# %% [markdown]
# <p>In this section, I will be interpreting the Clusters and finding out why certain data points are determined as a cluster and the average and key features that differentiate a cluster from another cluster. There will be multiple analysis done in this section and also visualisations.</p>

# %% [markdown]
# <hr/>
# <h2>7.1 Reversing Scaling</h2>

# %% [markdown]
# <p>In order to interpret our clustering effectively and accurately, we will firstly need to reverse the Z-Score Standardisation that was previously applied to the data. This will allow us to get back the original values for each of the data which removes the need for guessing the initial value. This operation will be done in the cell below.</p>

# %%
# ---------- Inverse Scaling ---------- #
df_zscore[features_to_scale] = scaler_zscore.inverse_transform(df_zscore[features_to_scale])

# ----------- Dropping t-SNE Data Columns ---------- #
df_zscore.drop(["TSNE1", "TSNE2"], axis=1, inplace=True)

# ---------- Displaying DataFrame ---------- #
df_zscore.head(5).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_72dcf_row0_col0, #T_72dcf_row0_col1, #T_72dcf_row1_col1, #T_72dcf_row2_col2, #T_72dcf_row2_col3, #T_72dcf_row2_col4, #T_72dcf_row3_col3, #T_72dcf_row4_col3, #T_72dcf_row4_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_72dcf_row0_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_72dcf_row0_col3, #T_72dcf_row0_col4, #T_72dcf_row1_col2, #T_72dcf_row1_col3, #T_72dcf_row1_col4, #T_72dcf_row3_col4, #T_72dcf_row4_col0, #T_72dcf_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_72dcf_row1_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_72dcf_row2_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_72dcf_row2_col1, #T_72dcf_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_72dcf_row3_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_72dcf_row3_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_72dcf_row4_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# </style>
# <table id="T_72dcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72dcf_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_72dcf_level0_col1" class="col_heading level0 col1" >Income (k$)</th>
#       <th id="T_72dcf_level0_col2" class="col_heading level0 col2" >How Much They Spend</th>
#       <th id="T_72dcf_level0_col3" class="col_heading level0 col3" >Gender_Male</th>
#       <th id="T_72dcf_level0_col4" class="col_heading level0 col4" >Cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72dcf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72dcf_row0_col0" class="data row0 col0" >19.000000</td>
#       <td id="T_72dcf_row0_col1" class="data row0 col1" >15.000000</td>
#       <td id="T_72dcf_row0_col2" class="data row0 col2" >39.000000</td>
#       <td id="T_72dcf_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_72dcf_row0_col4" class="data row0 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_72dcf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72dcf_row1_col0" class="data row1 col0" >21.000000</td>
#       <td id="T_72dcf_row1_col1" class="data row1 col1" >15.000000</td>
#       <td id="T_72dcf_row1_col2" class="data row1 col2" >81.000000</td>
#       <td id="T_72dcf_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_72dcf_row1_col4" class="data row1 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_72dcf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72dcf_row2_col0" class="data row2 col0" >20.000000</td>
#       <td id="T_72dcf_row2_col1" class="data row2 col1" >16.000000</td>
#       <td id="T_72dcf_row2_col2" class="data row2 col2" >6.000000</td>
#       <td id="T_72dcf_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_72dcf_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_72dcf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72dcf_row3_col0" class="data row3 col0" >23.000000</td>
#       <td id="T_72dcf_row3_col1" class="data row3 col1" >16.000000</td>
#       <td id="T_72dcf_row3_col2" class="data row3 col2" >77.000000</td>
#       <td id="T_72dcf_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_72dcf_row3_col4" class="data row3 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_72dcf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72dcf_row4_col0" class="data row4 col0" >31.000000</td>
#       <td id="T_72dcf_row4_col1" class="data row4 col1" >17.000000</td>
#       <td id="T_72dcf_row4_col2" class="data row4 col2" >40.000000</td>
#       <td id="T_72dcf_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_72dcf_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p>With reference to the output of the DataFrame above, I am able to confirm that the Data have been successfully reverse scaled and are more interpretable now.</p>

# %% [markdown]
# <hr/>
# <h2>7.2 Decision Tree Interpretation</h2>

# %% [markdown]
# <p>In this sub-section, I will be plotting out the Decision Tree plot to analyse and interpret what causes a certain data to be clustered under a specific cluster. This will provide some insights on an unsupervised model and also give us an opportunity to try to interpret what are the key deciding factors for clusters. We will be putting the target as Y and the features as X.</p>

# %%
# ----------- Data Preparation ----------- #
X = df_zscore[features_to_scale]
y = df_zscore['Cluster']

# ----------- Initiating Decision Tree Classifier ------------ #
dtree = DecisionTreeClassifier(random_state=42, max_depth=6)

# ----------- Training Decision Tree Classifier ------------ #
dtree.fit(X, y)

# ---------- Plotting Decision Tree ---------- #
plt.figure(figsize=(20, 20))
plot_tree(dtree, feature_names=features_to_scale, class_names=[str(c) for c in set(y)], filled=True, fontsize=10)
plt.title("Decision Tree for Cluster Explanation")
plt.show()

# %% [markdown]
# <p>With reference to the output of the Decision Tree plot above, I am able to see how are the clusters being clustered by the K-Means. The observations are listed below.</p>
# <br/>
# <p><strong><u>Splits</u></strong></p>
# <ul>
#     <li>The most important split which is the major deciding factor is the 'How much they spend'. This means Customers who spend more than 60.5 are immediately either placed in Cluster 2 or 5. This suggest spending plays a crucial role in the clustering.</li>
#     <li>The second most important split is based on the 'Income (k$)'. This imply that higher income groups are separated from lower income groups with threshold of 70.5k, 54k, etc.</li>
#     <li>The third most important split is based on the 'Age'. This implies that demographics are not as important as monetary value.</li>
# </ul>
# <p><strong><u>Clusters Interpretation</u></strong></p>
# <ul>
#     <li>Cluster 0: Lowest Income-Group With Lowest Spending (21 Customers)</li>
#     <li>Cluster 1: Younger Demographic With Moderate Income With Moderate Spending (40 Customers)</li>
#     <li>Cluster 2: High Income And High Spending (38 Customers)</li>
#     <li>Cluster 3: High Income Group With Low Spending (31 Customers)</li>
#     <li>Cluster 4: Older Demographic With Moderate Income And Moderate Spending (44 Customers)</li>
#     <li>Cluster 5: Low Income With High Spending (24 Customers)</li>
# </ul>
# <br/>
# <p>With the clustering factors and each cluster's representation indcated, I will proceed with gathering Implications and Insights on each of the clusters.</p>

# %% [markdown]
# <hr/>
# <h1>8. Implications And Insights Of Clusters</h1>

# %% [markdown]
# <p>In this section, I will be gathering Insights and listing their Implications for businesses. This will help our stakeholders improve their customer quality and also possibly improve their profit margins so as to divert manpower resources and utilising other methods and resources to create a contingency plan to cater to the different clusters of Customers.</p>

# %% [markdown]
# <hr/>
# <h2>8.1 Ratio Of Clusters</h2>

# %% [markdown]
# <p>Within this sub-section, I will be visualising the ratio of Clusters to see which clusters has the most amount of Customers so as to decide which Clusters need the most resources and planning so as to cater to the customers within that cluster. I will be utilising a Pie Chart so as to also compare with the rest of the Clusters.</p>

# %%
# ----------- Seaborn Theme ----------- #
sns.set_theme(style="whitegrid")

# ----------- Get Cluster Counts ----------- #
cluster_counts = df_zscore['Cluster'].value_counts()

# ----------- Defining Colour Palette ----------- #
colors = sns.color_palette("Set3", len(cluster_counts))

# ----------- Exploding Highest Counts ----------- #
explode = [0.1 if i == cluster_counts.idxmax() else 0 for i in cluster_counts.index]

# ----------- Plotting Pie Chart ----------- #
fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(
    cluster_counts, labels=[f"Cluster {i}" for i in cluster_counts.index], autopct='%1.1f%%',
    startangle=140, colors=colors, explode=explode, shadow=True,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1.2}, textprops={'fontsize': 12}
)

# ----------- Text And Labels ----------- #
for text in texts:
    text.set_fontsize(13)
    text.set_fontweight('bold')

for autotext in autotexts:
    autotext.set_fontsize(12)
    autotext.set_fontweight('bold')
    autotext.set_color('black')

# ----------- Add Title ----------- #
ax.set_title("Cluster Percentage Distribution", fontsize=16, fontweight='bold', pad=20)

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the Pie Chart above, I am able to see that Cluster 4 makes up the most percentage at 22.2% followed by Cluster 1 at 20.2% and Cluster 2 at 19.2%. These three clusters form the majority of the Total Dataset and should be paid close attention to due to it being 61.4% of the data. I have listed the implications below.</p>
# <br/>
# <p><strong><u>Cluster 4</u></strong></p>
# <ul>
#     <li>Cluster Properties: Older Demographic With Moderate Income And Moderate Spending.</li>
#     <li>Cluster 4 represents the older mainstream customers who do not spend much but still spends.</li>
#     <li>Most Manpower should be dedicated to assisting and catering to these Customers as most of the revenue will come from them due to their large numbers.</li>
#     <li>A mixture of experienced and less experienced should be allowed to handle Customers from Cluster 4.</li>
#     <li>Manpower should be distributed on a need basis for Customer from Cluster 4 (e.g. A staff helps the customer whenever he is available).</li>
#     <li>Manpower will need to be sufficient at each outlet as the Older Demographic will prefer purchasing items in person.</li>
# </ul>
# <p><strong><u>Cluster 1</u></strong></p>
# <ul>
#     <li>Cluster Properties: Younger Demographic With Moderate Income With Moderate Spending.</li>
#     <li>Cluster 1 represents the younger mainstream customers who do not spend much but still spends.</li>
#     <li>Manpower should be distributed the least for Customers who are in this Cluster as the revenue from these Customers are extremely minimal despite being a large part of the total Customer population. However, a high standard of Hospitality and Customer Service Excellence should still be maintained.</li>
#     <li>A reward's programme can be set up so as to transition Customers who are Clustered as Cluster 1 to Cluster 2, so as to increase the revenue earned from these Customers.</li>
#     <li>May be more responsive towards an online shopping portal due to the younger demographic.</li>
# </ul>
# <p><strong><u>Cluster 2</u></strong></p>
# <ul>
#     <li>Cluster Properties: High Income And High Spending</li>
#     <li>Cluster 2 Customers hold the highest priority as these Customers bring in the most revenue.</li>
#     <li>Only experienced Customer Engagement Officer should engage these customers to ensure the highest of standards of Customer Service are provided to these Customers.</li>
#     <li>High Quality or Limited Edition items should be introduced so as to capture the attention of these Customers and allow for higher profit margin within the companny from Sales as these Customers also have higher spending power.</li>
# </ul>
# <br/>
# <p>With the Cluster Percentage Distribution's observation and implication stated, I will now proceed to visualise the distribution of various data across clusters.</p>

# %% [markdown]
# <hr/>
# <h2>8.2 Distribution Of Age Across Clusters</h2>

# %% [markdown]
# <p>In this sub-section, we will be visualising the distribution of Age across the different Clusters so as to determine if a specific age group should be targetted. I will be utilising a Box Plot to see the distribution and will subsequently list down the age range for each of the clusters and also the </p>

# %%
# ----------- Seaborn Theme ----------- #
sns.set_theme(style="whitegrid")

# ----------- Defining Figure ----------- #
plt.figure(figsize=(12, 7))

# ----------- Enhanced Boxplot ----------- #
sns.boxplot(
    x='Cluster', y='Age', data=df_zscore, 
    palette='viridis', width=0.6, linewidth=1.5, 
    boxprops={'edgecolor': 'black', 'linewidth': 1.5},
    medianprops={'color': 'red', 'linewidth': 2}
)

# ----------- Titles And Labels ----------- #
plt.title("Age Distribution Across Clusters", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Cluster", fontsize=14, fontweight='bold', labelpad=10)
plt.ylabel("Age", fontsize=14, fontweight='bold', labelpad=10)

# ----------- Adding Grid ----------- #
plt.grid(axis='y', linestyle='--', alpha=0.6)

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Box plot above, I am able to see the range of ages and median age for each of the Clusters. The observations and implications are listed below.</p>
# <br/>
# <p><strong><u>Cluster 0</u></strong></p>
# <ul>
#     <li>Properties: Lowest Income-Group With Lowest Spending</li>
#     <li>Range of Age: 20 to 67 Years Old</li>
#     <li>Median Age: 46 Years Old</li>
# </ul>
# <p><strong><u>Cluster 1</u></strong></p>
# <ul>
#     <li>Properties: Younger Demographic With Moderate Income With Moderate Spending</li>
#     <li>Range of Age 18 to 40 Years Old</li>
#     <li>Median Age: 25 Years Old</li>
# </ul>
# <p><strong><u>Cluster 2</u></strong></p>
# <ul>
#     <li>Properties: High Income And High Spending</li>
#     <li>Range of Age: 27 to 40 Years Old</li>
#     <li>Median Age: 32 Years Old</li>
# </ul>
# <p><strong><u>Cluster 3</u></strong></p>
# <ul>
#     <li>Properties: High Income Group With Low Spending</li>
#     <li>Range of Age: 25 to 59 Years Old</li>
#     <li>Median Age: 45 Years Old</li>
# </ul>
# <p><strong><u>Cluster 4</u></strong></p>
# <ul>
#     <li>Properties: Older Demographic With Moderate Income And Moderate Spending</li>
#     <li>Range of Age: 43 to 70 Years Old</li>
#     <li>Median Age: 54 Years Old</li>
# </ul>
# <p><strong><u>Cluster 5</u></strong></p>
# <ul>
#     <li>Properties: Low Income With High Spending</li>
#     <li>Range of Age: 18 to 35 Years Old</li>
#     <li>Median Age: 24 Years Old</li>
# </ul>
# <br/>
# <p>With reference to the range of ages, I am able to make the following business implications</p>
# <br/>
# <ul>
#     <li>High Spenders who will bring in large amount of profits are aged 18 Years Old to 40 Years Old. Therefore, more attention should be paid to these Customers as these Customers bring in the highest profit margin for the company and also most likely more demanding than other Customers. Thus, more experienced staff should be on standby to entertain and engage these Customers to ensure their satisfaction and potentially upselling to these Customers.</li>
#     <li>Some staff should be on stand by to cater to a potential high value customer while most of the staff engage with Customers in general.</li>
#     <li>Staff should not discriminate against the age of any Customers as the range of Customers who spends money in general is from 18 to 70 Years Old.</li>
#     <li>Companies should consider adopting a hybrid approach to selling items such as utilising Online Shopping Platforms and Social Media as the median age of High Spenders are around 23 and 32 Years Old, which means these demographics most likely prefer purchasing items through Online Shopping rather than in-person.</li>
#     <li>Staff should look out for Customers aged 24 and 32 as these are the Median age for high spending customers.</li>
# </ul>
# <br/>
# <p>With the Implications indicated, I will proceed to conduct the Visualisation on the Income Distribution in the next sub-section.</p>

# %% [markdown]
# <hr/>
# <h2>8.3 Distribution Of Income Across Clusters</h2>

# %% [markdown]
# <p>In this sub-section, we will be visualising the distribution of Income across the different Clusters so as to determine if a specific age group should be targetted. I will be utilising a Box Plot to see the distribution and will subsequently list down the age range for each of the clusters and also the </p>

# %%
# ----------- Seaborn Theme ----------- #
sns.set_theme(style="whitegrid")

# ----------- Defining Figure ----------- #
plt.figure(figsize=(12, 7))

# ----------- Plotting Boxplots ----------- #
sns.boxplot(
    x='Cluster', y='Income (k$)', data=df_zscore, 
    palette='viridis', width=0.6, linewidth=1.5, 
    boxprops={'edgecolor': 'black', 'linewidth': 1.5},  # Darker borders
    medianprops={'color': 'red', 'linewidth': 2}  # Highlight median in red
)

# ----------- Titles And Labels ----------- #
plt.title("Income Distribution Across Clusters", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Cluster", fontsize=14, fontweight='bold', labelpad=10)
plt.ylabel("Income (k$)", fontsize=14, fontweight='bold', labelpad=10)

# ----------- Adding Grid ----------- #
plt.grid(axis='y', linestyle='--', alpha=0.6)

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Box plot above, I am able to see the range of Income and median Income for each of the Clusters. The observations and implications are listed below.</p>
# <br/>
# <p><strong><u>Cluster 0</u></strong></p>
# <ul>
#     <li>Properties: Lowest Income-Group With Lowest Spending</li>
#     <li>Range of Age: 20 to 67 Years Old</li>
#     <li>Median Age: 46 Years Old</li>
#     <li>Range of Income: 18k to 39k</li>
#     <li>Median Income: 25k</li>
# </ul>
# <p><strong><u>Cluster 1</u></strong></p>
# <ul>
#     <li>Properties: Lower Income With Lower Spending</li>
#     <li>Range of Age 18 to 40 Years Old</li>
#     <li>Median Age: 25 Years Old</li>
#     <li>Range of Income: 40k to 81k</li>
#     <li>Median Income: 60k</li>
# </ul>
# <p><strong><u>Cluster 2</u></strong></p>
# <ul>
#     <li>Properties: High Income And High Spending</li>
#     <li>Range of Age: 27 to 40 Years Old</li>
#     <li>Median Age: 32 Years Old</li>
#     <li>Range of Income: 70k to 130k</li>
#     <li>Median Income: 79k</li>
# </ul>
# <p><strong><u>Cluster 3</u></strong></p>
# <ul>
#     <li>Properties: Young Individuals With Medium Income And Spending</li>
#     <li>Range of Age: 25 to 59 Years Old</li>
#     <li>Median Age: 45 Years Old</li>
#     <li>Range of Income: 70k to 130k</li>
#     <li>Median Income: 84k</li>
# </ul>
# <p><strong><u>Cluster 4</u></strong></p>
# <ul>
#     <li>Properties: Moderate Spenders And Medium Income Range</li>
#     <li>Range of Age: 43 to 70 Years Old</li>
#     <li>Median Age: 54 Years Old</li>
#     <li>Range of Income: 38k to 68k</li>
#     <li>Median Income: 56k</li>
# </ul>
# <p><strong><u>Cluster 5</u></strong></p>
# <ul>
#     <li>Properties: Very High Spenders With Very Low Income</li>
#     <li>Range of Age: 18 to 35 Years Old</li>
#     <li>Median Age: 24 Years Old</li>
#     <li>Range of Income: 18k to 39k</li>
#     <li>Median Income: 25k</li>
# </ul>
# <br/>
# <p>With reference to the range of ages, I am able to make the following business implications</p>
# <br/>
# <ul>
#     <li>The high spenders have a range on income of 40k to 130k, with median being 79k. This shows the amount of spending power these individuals have which implies that Customer Service Officers should look out for customers in the age range of 27 to 40 Years old and especially for Customers who are in their 30s since the median age is 32 Years Old.</li>
#     <li>Customers Service Officers should also take note that Genders are clustered together. Therefore, it is extremely important not to discriminate against a particular Gender.</li>
#     <li>Customers in Cluster 0 and Cluster 5 have the lowest median income. However, cluster 5 is determined to have a high spending, which indicates that payment made need to be cautious in the event that the payment method is not approved.</li>
# </ul>
# <br/>
# <p>With the Implications indicated, I will proceed to conduct the Visualisation on the Spending Distribution in the next sub-section.</p>

# %% [markdown]
# <hr/>
# <h2>8.4 Distribution Of Spending Across Clusters</h2>

# %% [markdown]
# <p>In this sub-section, we will be visualising the distribution of Spending across the different Clusters so as to determine if a specific age group should be targetted. I will be utilising a Box Plot to see the distribution and will subsequently list down the age range for each of the clusters and also the </p>

# %%
# ----------- Seaborn Theme ----------- #
sns.set_theme(style="whitegrid")

# ----------- Defining Figure Size ----------- #
plt.figure(figsize=(12, 7))

# ----------- Plotting Boxplot ----------- #
sns.boxplot(
    x='Cluster', y='How Much They Spend', data=df_zscore, 
    palette='viridis', width=0.6, linewidth=1.5, 
    boxprops={'edgecolor': 'black', 'linewidth': 1.5},  # Darker borders
    medianprops={'color': 'red', 'linewidth': 2}  # Highlight median in red
)

# ----------- Titles And Labels ----------- #
plt.title("Spending Distribution Across Clusters", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Cluster", fontsize=14, fontweight='bold', labelpad=10)
plt.ylabel("Spending", fontsize=14, fontweight='bold', labelpad=10)

# ----------- Adding Grid ----------- #
plt.grid(axis='y', linestyle='--', alpha=0.6)

# ----------- Displaying Plot ----------- #
plt.show()

# %% [markdown]
# <p>With reference to the output of the Box plot above, I am able to see the range of Income and median Income for each of the Clusters. The observations and implications are listed below.</p>
# <br/>
# <p><strong><u>Cluster 0</u></strong></p>
# <ul>
#     <li>Properties: Lowest Income-Group With Lowest Spending</li>
#     <li>Range of Age: 20 to 67 Years Old</li>
#     <li>Median Age: 46 Years Old</li>
#     <li>Range of Income: 18k to 39k</li>
#     <li>Median Income: 25k</li>
#     <li>Range of Spending: 2 to 40</li>
#     <li>Median Spending 17</li>
# </ul>
# <p><strong><u>Cluster 1</u></strong></p>
# <ul>
#     <li>Properties: Lower Income With Lower Spending</li>
#     <li>Range of Age 18 to 40 Years Old</li>
#     <li>Median Age: 25 Years Old</li>
#     <li>Range of Income: 40k to 81k</li>
#     <li>Median Income: 60k</li>
#     <li>Range of Spending: 5 to 60</li>
#     <li>Median Spending 17</li>
# </ul>
# <p><strong><u>Cluster 2</u></strong></p>
# <ul>
#     <li>Properties: High Income And High Spending</li>
#     <li>Range of Age: 27 to 40 Years Old</li>
#     <li>Median Age: 32 Years Old</li>
#     <li>Range of Income: 70k to 130k</li>
#     <li>Median Income: 79k</li>
#     <li>Range of Spending: 62 to 95</li>
#     <li>Median Spending 17</li>
# </ul>
# <p><strong><u>Cluster 3</u></strong></p>
# <ul>
#     <li>Properties: Young Individuals With Medium Income And Spending</li>
#     <li>Range of Age: 25 to 59 Years Old</li>
#     <li>Median Age: 45 Years Old</li>
#     <li>Range of Income: 70k to 130k</li>
#     <li>Median Income: 84k</li>
#     <li>Range of Spending: 1 to 39</li>
#     <li>Median Spending 17</li>
# </ul>
# <p><strong><u>Cluster 4</u></strong></p>
# <ul>
#     <li>Properties: Moderate Spenders And Medium Income Range</li>
#     <li>Range of Age: 43 to 70 Years Old</li>
#     <li>Median Age: 54 Years Old</li>
#     <li>Range of Income: 38k to 68k</li>
#     <li>Median Income: 56k</li>
#     <li>Range of Spending: 35 to 60</li>
#     <li>Median Spending 17</li>
# </ul>
# <p><strong><u>Cluster 5</u></strong></p>
# <ul>
#     <li>Properties: Very High Spenders With Very Low Income</li>
#     <li>Range of Age: 18 to 35 Years Old</li>
#     <li>Median Age: 24 Years Old</li>
#     <li>Range of Income: 18k to 39k</li>
#     <li>Median Income: 25k</li>
#     <li>Range of Spending: 39 to 99</li>
#     <li>Median Spending 17</li>
# </ul>
# <br/>
# <p>With reference to the range of ages, I am able to make the following business implications</p>
# <br/>
# <ul>
#     <li>Despite some clusters having a small range of spending, the Customers are still spending money. Therefore, Customer Service Officers should not be discriminating against anyone as all the customers are still spending money which contributes to the total revenue.</li>
#     <li>Customer Service Officers should take note of Customers who fall under the Cluster 3 as these Customers are spending very little but they have the spending power. Therefore, upselling techniques should be used by staff to try to increase revenue..</li>
#     <li>Some Clusters may have outliers within them such as Cluster 1 which indicates that despite the Clusterign to boost revenue, there will still be exceptions and the staff should ultimately exercise discretion when dealing with Customers.</li>
# </ul>
# <br/>
# <p>With the Implications indicated, I hereby conclude the Part B of CA 2.</p>
